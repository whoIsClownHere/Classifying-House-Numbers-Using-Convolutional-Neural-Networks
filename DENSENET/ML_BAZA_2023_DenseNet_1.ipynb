# %% [markdown]
# **ДЛЯ ТЕХ КТО НА COLAB** ,следующие 2 бокса
#
# Шаг 2: Загрузка учетных данных API
# Чтобы загрузить данные из Kaggle, необходимо пройти аутентификацию в сервисах Kaggle. Для этого понадобится API-токен. Его можно сгенерировать в разделе профиля учетной записи пользователя Kaggle.
#
# Сначала перейдите в свой профиль Kaggle:
#
#
# Теперь откройте вкладку “Account” (“Аккаунт”) и опуститесь до раздела “API” (скриншот из профиля Kaggle).
#
# Будет загружен файл с именем “kaggle.json”, который содержит имя пользователя и ключ API.
#
# Это одноразовый шаг, так что вам не придется генерировать учетные данные всякий раз при загрузке набора данных.
#
# https://medium.com/nuances-of-programming/%D0%BA%D0%B0%D0%BA-%D0%B8%D0%BC%D0%BF%D0%BE%D1%80%D1%82%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D1%82%D1%8C-%D0%BD%D0%B0%D0%B1%D0%BE%D1%80%D1%8B-%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85-kaggle-%D0%B2-google-colab-51de3fd5a9a8#:~:text=%D0%97%D0%B0%D0%BF%D1%83%D1%81%D1%82%D0%B8%D1%82%D0%B5%20%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%20Google%20Colab%20%D0%B8,%D0%BD%D0%B5%D0%BE%D0%B1%D1%85%D0%BE%D0%B4%D0%B8%D0%BC%D1%8B%D1%85%20%D0%B4%D0%BB%D1%8F%20%D0%B7%D0%B0%D0%B3%D1%80%D1%83%D0%B7%D0%BA%D0%B8%20%D0%BD%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85

# %%
# https://medium.com/nuances-of-programming/%D0%BA%D0%B0%D0%BA-%D0%B8%D0%BC%D0%BF%D0%BE%D1%80%D1%82%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D1%82%D1%8C-%D0%BD%D0%B0%D0%B1%D0%BE%D1%80%D1%8B-%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85-kaggle-%D0%B2-google-colab-51de3fd5a9a8#:~:text=%D0%97%D0%B0%D0%BF%D1%83%D1%81%D1%82%D0%B8%D1%82%D0%B5%20%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%20Google%20Colab%20%D0%B8,%D0%BD%D0%B5%D0%BE%D0%B1%D1%85%D0%BE%D0%B4%D0%B8%D0%BC%D1%8B%D1%85%20%D0%B4%D0%BB%D1%8F%20%D0%B7%D0%B0%D0%B3%D1%80%D1%83%D0%B7%D0%BA%D0%B8%20%D0%BD%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85.
# Как импортировать наборы данных Kaggle в Google Colab?
# Сделать ШАГ 2 
# Также есть Лайфхак 2: Загрузка учетных данных Kaggle из Google Drive , чтобы каждый раз загружать kaggle.json
! mkdir ~/.kaggle

! cp kaggle.json ~/.kaggle/

! chmod 600 ~/.kaggle/kaggle.json

! kaggle competitions download ml-intensive-of-yandex-academy-2023 #Но аккаунт должен быть зарегистрирован на соревновании
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# Downloading ml-intensive-of-yandex-academy-2023.zip to /content
#  93% 244M/263M [00:01<00:00, 149MB/s]
# 100% 263M/263M [00:02<00:00, 132MB/s]

# %% [markdown]
# https://ru.stackoverflow.com/questions/1061024/%D0%94%D0%BE%D1%81%D1%82%D1%83%D0%BF-%D0%BA-%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0%D0%BC-zip-%D0%B0%D1%80%D1%85%D0%B8%D0%B2%D0%B0-%D0%B2-google-colab

# %%
# https://ru.stackoverflow.com/questions/1061024/%D0%94%D0%BE%D1%81%D1%82%D1%83%D0%BF-%D0%BA-%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0%D0%BC-zip-%D0%B0%D1%80%D1%85%D0%B8%D0%B2%D0%B0-%D0%B2-google-colab
# Доступ к папкам ZIP-архива в Google Colab
import zipfile
import os

data_r = zipfile.ZipFile('ml-intensive-of-yandex-academy-2023.zip', 'r')
data_r.printdir()
data_r.extractall()
# Out:
# File Name                                             Modified             Size
# data_test                                      2023-04-04 08:27:46    307200197
# data_train                                     2023-04-04 08:28:10    614450277
# meta                                           2023-04-04 08:29:00           73

# %% [markdown]
# **ОТСЮДА УЖЕ ДЛЯ ВСЕХ**

# %%
# http://cs.mipt.ru/advanced_python/lessons/lab13.html
# Теперь в отдельной программе выполним десериализацию. Это уже надо всем делать.
import pickle

# Data_train
with open('data_train', 'rb') as f:
    data_train = pickle.load(f)
print(data_train)
# Data_test
with open('data_test', 'rb') as f:
    data_test = pickle.load(f)
print(data_test)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline
from tensorflow.keras import layers

# %%
# ДАТАСЕТ
x_train_full = data_train['images']
y_train_full = data_train['labels']

x_test = data_test['images']
x_train_full, x_test = x_train_full / 255.0, x_test / 255.0

# %%
n_values = 10

# YOUR CODE HERE
y_train_full_one_hot = tf.one_hot(y_train_full, n_values)
# y_test_one_hot = tf.one_hot(test_images, n_values)

# %%
val_size = 0.1
batch_size = 256
size = x_train_full.shape[0]

x_val, y_val_one_hot = x_train_full[:int(size * 0.1)], y_train_full_one_hot[:int(size * 0.1)]
x_train, y_train_one_hot = x_train_full[int(size * 0.1):], y_train_full_one_hot[int(size * 0.1):]

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train_one_hot))
train_dataset = train_dataset.shuffle(1024)
train_dataset = train_dataset.batch(batch_size)

val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val_one_hot))
val_dataset = val_dataset.shuffle(1024)
val_dataset = val_dataset.batch(batch_size)

# %%
! pip install livelossplot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting livelossplot
#   Downloading livelossplot-0.5.5-py3-none-any.whl (22 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from livelossplot) (3.7.1)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.9/dist-packages (from livelossplot) (2.4.3)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (3.1.2)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (23.0)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (8.4.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (4.5.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (6.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (1.22.4)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (4.39.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (0.11.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->livelossplot) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=2.9->bokeh->livelossplot) (2.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->livelossplot) (1.16.0)
# Installing collected packages: livelossplot
# Successfully installed livelossplot-0.5.5

# %%
from tensorflow.keras import layers

#СОЗДАЕМ МОДЕЛЬ 
input_shape = x_train.shape[-3:]

import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, Conv3D, DepthwiseConv2D, SeparableConv2D, Conv3DTranspose
from keras.layers import Flatten, MaxPool2D, AvgPool2D, GlobalAvgPool2D, UpSampling2D, BatchNormalization
from keras.layers import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

from time import time
import numpy as np
     

def densenet(img_shape, n_classes, f=32):
  repetitions = 6, 12, 24, 16
  
  def bn_rl_conv(x, f, k=1, s=1, p='same'):
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)
    x = ReLU()(x)
    x = Conv2D(f, k, strides=s, padding=p)(x)
    return x
  
  
  def dense_block(tensor, r):
    for _ in range(r):
      x = bn_rl_conv(tensor, 4*f)
      x = bn_rl_conv(x, f, 3)
      tensor = Concatenate()([tensor, x])
    return tensor
  
  
  def transition_block(x):
    x = bn_rl_conv(x, K.int_shape(x)[-1] // 2)
    x = AvgPool2D(2, strides=2, padding='same')(x)
    return x
  
  
  input = Input(img_shape)
  
  x = Conv2D(64, 7, strides=2, padding='same')(input)
  x = MaxPool2D(3, strides=2, padding='same')(x)
  
  for r in repetitions:
    d = dense_block(x, r)
    x = transition_block(d)
  
  x = GlobalAvgPool2D()(d)
  
  output = Dense(n_classes, activation='softmax')(x)
  
  model = Model(input, output)
  return model

model = densenet(input_shape, 10)

# Компиляция и обучение модели
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_122 (Conv2D)            (None, 16, 16, 64)   9472        ['input_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)    0           ['conv2d_122[0][0]']
#
#  batch_normalization_120 (Batch  (None, 8, 8, 64)    256         ['max_pooling2d_1[0][0]']
#  Normalization)
#
#  dropout (Dropout)              (None, 8, 8, 64)     0           ['batch_normalization_120[0][0]']
#
#  re_lu_120 (ReLU)               (None, 8, 8, 64)     0           ['dropout[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 8, 8, 128)    8320        ['re_lu_120[0][0]']
#
#  batch_normalization_121 (Batch  (None, 8, 8, 128)   512         ['conv2d_123[0][0]']
#  Normalization)
#
#  dropout_1 (Dropout)            (None, 8, 8, 128)    0           ['batch_normalization_121[0][0]']
#
#  re_lu_121 (ReLU)               (None, 8, 8, 128)    0           ['dropout_1[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 8, 8, 32)     36896       ['re_lu_121[0][0]']
#
#  concatenate_58 (Concatenate)   (None, 8, 8, 96)     0           ['max_pooling2d_1[0][0]',
#                                                                   'conv2d_124[0][0]']
#
#  batch_normalization_122 (Batch  (None, 8, 8, 96)    384         ['concatenate_58[0][0]']
#  Normalization)
#
#  dropout_2 (Dropout)            (None, 8, 8, 96)     0           ['batch_normalization_122[0][0]']
#
#  re_lu_122 (ReLU)               (None, 8, 8, 96)     0           ['dropout_2[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 8, 8, 128)    12416       ['re_lu_122[0][0]']
#
#  batch_normalization_123 (Batch  (None, 8, 8, 128)   512         ['conv2d_125[0][0]']
#  Normalization)
#
#  dropout_3 (Dropout)            (None, 8, 8, 128)    0           ['batch_normalization_123[0][0]']
#
#  re_lu_123 (ReLU)               (None, 8, 8, 128)    0           ['dropout_3[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 8, 8, 32)     36896       ['re_lu_123[0][0]']
#
#  concatenate_59 (Concatenate)   (None, 8, 8, 128)    0           ['concatenate_58[0][0]',
#                                                                   'conv2d_126[0][0]']
#
#  batch_normalization_124 (Batch  (None, 8, 8, 128)   512         ['concatenate_59[0][0]']
#  Normalization)
#
#  dropout_4 (Dropout)            (None, 8, 8, 128)    0           ['batch_normalization_124[0][0]']
#
#  re_lu_124 (ReLU)               (None, 8, 8, 128)    0           ['dropout_4[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 8, 8, 128)    16512       ['re_lu_124[0][0]']
#
#  batch_normalization_125 (Batch  (None, 8, 8, 128)   512         ['conv2d_127[0][0]']
#  Normalization)
#
#  dropout_5 (Dropout)            (None, 8, 8, 128)    0           ['batch_normalization_125[0][0]']
#
#  re_lu_125 (ReLU)               (None, 8, 8, 128)    0           ['dropout_5[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 8, 8, 32)     36896       ['re_lu_125[0][0]']
#
#  concatenate_60 (Concatenate)   (None, 8, 8, 160)    0           ['concatenate_59[0][0]',
#                                                                   'conv2d_128[0][0]']
#
#  batch_normalization_126 (Batch  (None, 8, 8, 160)   640         ['concatenate_60[0][0]']
#  Normalization)
#
#  dropout_6 (Dropout)            (None, 8, 8, 160)    0           ['batch_normalization_126[0][0]']
#
#  re_lu_126 (ReLU)               (None, 8, 8, 160)    0           ['dropout_6[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 8, 8, 128)    20608       ['re_lu_126[0][0]']
#
#  batch_normalization_127 (Batch  (None, 8, 8, 128)   512         ['conv2d_129[0][0]']
#  Normalization)
#
#  dropout_7 (Dropout)            (None, 8, 8, 128)    0           ['batch_normalization_127[0][0]']
#
#  re_lu_127 (ReLU)               (None, 8, 8, 128)    0           ['dropout_7[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 8, 8, 32)     36896       ['re_lu_127[0][0]']
#
#  concatenate_61 (Concatenate)   (None, 8, 8, 192)    0           ['concatenate_60[0][0]',
#                                                                   'conv2d_130[0][0]']
#
#  batch_normalization_128 (Batch  (None, 8, 8, 192)   768         ['concatenate_61[0][0]']
#  Normalization)
#
#  dropout_8 (Dropout)            (None, 8, 8, 192)    0           ['batch_normalization_128[0][0]']
#
#  re_lu_128 (ReLU)               (None, 8, 8, 192)    0           ['dropout_8[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 8, 8, 128)    24704       ['re_lu_128[0][0]']
#
#  batch_normalization_129 (Batch  (None, 8, 8, 128)   512         ['conv2d_131[0][0]']
#  Normalization)
#
#  dropout_9 (Dropout)            (None, 8, 8, 128)    0           ['batch_normalization_129[0][0]']
#
#  re_lu_129 (ReLU)               (None, 8, 8, 128)    0           ['dropout_9[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 8, 8, 32)     36896       ['re_lu_129[0][0]']
#
#  concatenate_62 (Concatenate)   (None, 8, 8, 224)    0           ['concatenate_61[0][0]',
#                                                                   'conv2d_132[0][0]']
#
#  batch_normalization_130 (Batch  (None, 8, 8, 224)   896         ['concatenate_62[0][0]']
#  Normalization)
#
#  dropout_10 (Dropout)           (None, 8, 8, 224)    0           ['batch_normalization_130[0][0]']
#
#  re_lu_130 (ReLU)               (None, 8, 8, 224)    0           ['dropout_10[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 8, 8, 128)    28800       ['re_lu_130[0][0]']
#
#  batch_normalization_131 (Batch  (None, 8, 8, 128)   512         ['conv2d_133[0][0]']
#  Normalization)
#
#  dropout_11 (Dropout)           (None, 8, 8, 128)    0           ['batch_normalization_131[0][0]']
#
#  re_lu_131 (ReLU)               (None, 8, 8, 128)    0           ['dropout_11[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 8, 8, 32)     36896       ['re_lu_131[0][0]']
#
#  concatenate_63 (Concatenate)   (None, 8, 8, 256)    0           ['concatenate_62[0][0]',
#                                                                   'conv2d_134[0][0]']
#
#  batch_normalization_132 (Batch  (None, 8, 8, 256)   1024        ['concatenate_63[0][0]']
#  Normalization)
#
#  dropout_12 (Dropout)           (None, 8, 8, 256)    0           ['batch_normalization_132[0][0]']
#
#  re_lu_132 (ReLU)               (None, 8, 8, 256)    0           ['dropout_12[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 8, 8, 128)    32896       ['re_lu_132[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 4, 4, 128)   0           ['conv2d_135[0][0]']
#  oling2D)
#
#  batch_normalization_133 (Batch  (None, 4, 4, 128)   512         ['average_pooling2d_4[0][0]']
#  Normalization)
#
#  dropout_13 (Dropout)           (None, 4, 4, 128)    0           ['batch_normalization_133[0][0]']
#
#  re_lu_133 (ReLU)               (None, 4, 4, 128)    0           ['dropout_13[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 4, 4, 128)    16512       ['re_lu_133[0][0]']
#
#  batch_normalization_134 (Batch  (None, 4, 4, 128)   512         ['conv2d_136[0][0]']
#  Normalization)
#
#  dropout_14 (Dropout)           (None, 4, 4, 128)    0           ['batch_normalization_134[0][0]']
#
#  re_lu_134 (ReLU)               (None, 4, 4, 128)    0           ['dropout_14[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 4, 4, 32)     36896       ['re_lu_134[0][0]']
#
#  concatenate_64 (Concatenate)   (None, 4, 4, 160)    0           ['average_pooling2d_4[0][0]',
#                                                                   'conv2d_137[0][0]']
#
#  batch_normalization_135 (Batch  (None, 4, 4, 160)   640         ['concatenate_64[0][0]']
#  Normalization)
#
#  dropout_15 (Dropout)           (None, 4, 4, 160)    0           ['batch_normalization_135[0][0]']
#
#  re_lu_135 (ReLU)               (None, 4, 4, 160)    0           ['dropout_15[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 4, 4, 128)    20608       ['re_lu_135[0][0]']
#
#  batch_normalization_136 (Batch  (None, 4, 4, 128)   512         ['conv2d_138[0][0]']
#  Normalization)
#
#  dropout_16 (Dropout)           (None, 4, 4, 128)    0           ['batch_normalization_136[0][0]']
#
#  re_lu_136 (ReLU)               (None, 4, 4, 128)    0           ['dropout_16[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 4, 4, 32)     36896       ['re_lu_136[0][0]']
#
#  concatenate_65 (Concatenate)   (None, 4, 4, 192)    0           ['concatenate_64[0][0]',
#                                                                   'conv2d_139[0][0]']
#
#  batch_normalization_137 (Batch  (None, 4, 4, 192)   768         ['concatenate_65[0][0]']
#  Normalization)
#
#  dropout_17 (Dropout)           (None, 4, 4, 192)    0           ['batch_normalization_137[0][0]']
#
#  re_lu_137 (ReLU)               (None, 4, 4, 192)    0           ['dropout_17[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 4, 4, 128)    24704       ['re_lu_137[0][0]']
#
#  batch_normalization_138 (Batch  (None, 4, 4, 128)   512         ['conv2d_140[0][0]']
#  Normalization)
#
#  dropout_18 (Dropout)           (None, 4, 4, 128)    0           ['batch_normalization_138[0][0]']
#
#  re_lu_138 (ReLU)               (None, 4, 4, 128)    0           ['dropout_18[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 4, 4, 32)     36896       ['re_lu_138[0][0]']
#
#  concatenate_66 (Concatenate)   (None, 4, 4, 224)    0           ['concatenate_65[0][0]',
#                                                                   'conv2d_141[0][0]']
#
#  batch_normalization_139 (Batch  (None, 4, 4, 224)   896         ['concatenate_66[0][0]']
#  Normalization)
#
#  dropout_19 (Dropout)           (None, 4, 4, 224)    0           ['batch_normalization_139[0][0]']
#
#  re_lu_139 (ReLU)               (None, 4, 4, 224)    0           ['dropout_19[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 4, 4, 128)    28800       ['re_lu_139[0][0]']
#
#  batch_normalization_140 (Batch  (None, 4, 4, 128)   512         ['conv2d_142[0][0]']
#  Normalization)
#
#  dropout_20 (Dropout)           (None, 4, 4, 128)    0           ['batch_normalization_140[0][0]']
#
#  re_lu_140 (ReLU)               (None, 4, 4, 128)    0           ['dropout_20[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 4, 4, 32)     36896       ['re_lu_140[0][0]']
#
#  concatenate_67 (Concatenate)   (None, 4, 4, 256)    0           ['concatenate_66[0][0]',
#                                                                   'conv2d_143[0][0]']
#
#  batch_normalization_141 (Batch  (None, 4, 4, 256)   1024        ['concatenate_67[0][0]']
#  Normalization)
#
#  dropout_21 (Dropout)           (None, 4, 4, 256)    0           ['batch_normalization_141[0][0]']
#
#  re_lu_141 (ReLU)               (None, 4, 4, 256)    0           ['dropout_21[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 4, 4, 128)    32896       ['re_lu_141[0][0]']
#
#  batch_normalization_142 (Batch  (None, 4, 4, 128)   512         ['conv2d_144[0][0]']
#  Normalization)
#
#  dropout_22 (Dropout)           (None, 4, 4, 128)    0           ['batch_normalization_142[0][0]']
#
#  re_lu_142 (ReLU)               (None, 4, 4, 128)    0           ['dropout_22[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 4, 4, 32)     36896       ['re_lu_142[0][0]']
#
#  concatenate_68 (Concatenate)   (None, 4, 4, 288)    0           ['concatenate_67[0][0]',
#                                                                   'conv2d_145[0][0]']
#
#  batch_normalization_143 (Batch  (None, 4, 4, 288)   1152        ['concatenate_68[0][0]']
#  Normalization)
#
#  dropout_23 (Dropout)           (None, 4, 4, 288)    0           ['batch_normalization_143[0][0]']
#
#  re_lu_143 (ReLU)               (None, 4, 4, 288)    0           ['dropout_23[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 4, 4, 128)    36992       ['re_lu_143[0][0]']
#
#  batch_normalization_144 (Batch  (None, 4, 4, 128)   512         ['conv2d_146[0][0]']
#  Normalization)
#
#  dropout_24 (Dropout)           (None, 4, 4, 128)    0           ['batch_normalization_144[0][0]']
#
#  re_lu_144 (ReLU)               (None, 4, 4, 128)    0           ['dropout_24[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 4, 4, 32)     36896       ['re_lu_144[0][0]']
#
#  concatenate_69 (Concatenate)   (None, 4, 4, 320)    0           ['concatenate_68[0][0]',
#                                                                   'conv2d_147[0][0]']
#
#  batch_normalization_145 (Batch  (None, 4, 4, 320)   1280        ['concatenate_69[0][0]']
#  Normalization)
#
#  dropout_25 (Dropout)           (None, 4, 4, 320)    0           ['batch_normalization_145[0][0]']
#
#  re_lu_145 (ReLU)               (None, 4, 4, 320)    0           ['dropout_25[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 4, 4, 128)    41088       ['re_lu_145[0][0]']
#
#  batch_normalization_146 (Batch  (None, 4, 4, 128)   512         ['conv2d_148[0][0]']
#  Normalization)
#
#  dropout_26 (Dropout)           (None, 4, 4, 128)    0           ['batch_normalization_146[0][0]']
#
#  re_lu_146 (ReLU)               (None, 4, 4, 128)    0           ['dropout_26[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 4, 4, 32)     36896       ['re_lu_146[0][0]']
#
#  concatenate_70 (Concatenate)   (None, 4, 4, 352)    0           ['concatenate_69[0][0]',
#                                                                   'conv2d_149[0][0]']
#
#  batch_normalization_147 (Batch  (None, 4, 4, 352)   1408        ['concatenate_70[0][0]']
#  Normalization)
#
#  dropout_27 (Dropout)           (None, 4, 4, 352)    0           ['batch_normalization_147[0][0]']
#
#  re_lu_147 (ReLU)               (None, 4, 4, 352)    0           ['dropout_27[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 4, 4, 128)    45184       ['re_lu_147[0][0]']
#
#  batch_normalization_148 (Batch  (None, 4, 4, 128)   512         ['conv2d_150[0][0]']
#  Normalization)
#
#  dropout_28 (Dropout)           (None, 4, 4, 128)    0           ['batch_normalization_148[0][0]']
#
#  re_lu_148 (ReLU)               (None, 4, 4, 128)    0           ['dropout_28[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 4, 4, 32)     36896       ['re_lu_148[0][0]']
#
#  concatenate_71 (Concatenate)   (None, 4, 4, 384)    0           ['concatenate_70[0][0]',
#                                                                   'conv2d_151[0][0]']
#
#  batch_normalization_149 (Batch  (None, 4, 4, 384)   1536        ['concatenate_71[0][0]']
#  Normalization)
#
#  dropout_29 (Dropout)           (None, 4, 4, 384)    0           ['batch_normalization_149[0][0]']
#
#  re_lu_149 (ReLU)               (None, 4, 4, 384)    0           ['dropout_29[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 4, 4, 128)    49280       ['re_lu_149[0][0]']
#
#  batch_normalization_150 (Batch  (None, 4, 4, 128)   512         ['conv2d_152[0][0]']
#  Normalization)
#
#  dropout_30 (Dropout)           (None, 4, 4, 128)    0           ['batch_normalization_150[0][0]']
#
#  re_lu_150 (ReLU)               (None, 4, 4, 128)    0           ['dropout_30[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 4, 4, 32)     36896       ['re_lu_150[0][0]']
#
#  concatenate_72 (Concatenate)   (None, 4, 4, 416)    0           ['concatenate_71[0][0]',
#                                                                   'conv2d_153[0][0]']
#
#  batch_normalization_151 (Batch  (None, 4, 4, 416)   1664        ['concatenate_72[0][0]']
#  Normalization)
#
#  dropout_31 (Dropout)           (None, 4, 4, 416)    0           ['batch_normalization_151[0][0]']
#
#  re_lu_151 (ReLU)               (None, 4, 4, 416)    0           ['dropout_31[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 4, 4, 128)    53376       ['re_lu_151[0][0]']
#
#  batch_normalization_152 (Batch  (None, 4, 4, 128)   512         ['conv2d_154[0][0]']
#  Normalization)
#
#  dropout_32 (Dropout)           (None, 4, 4, 128)    0           ['batch_normalization_152[0][0]']
#
#  re_lu_152 (ReLU)               (None, 4, 4, 128)    0           ['dropout_32[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 4, 4, 32)     36896       ['re_lu_152[0][0]']
#
#  concatenate_73 (Concatenate)   (None, 4, 4, 448)    0           ['concatenate_72[0][0]',
#                                                                   'conv2d_155[0][0]']
#
#  batch_normalization_153 (Batch  (None, 4, 4, 448)   1792        ['concatenate_73[0][0]']
#  Normalization)
#
#  dropout_33 (Dropout)           (None, 4, 4, 448)    0           ['batch_normalization_153[0][0]']
#
#  re_lu_153 (ReLU)               (None, 4, 4, 448)    0           ['dropout_33[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 4, 4, 128)    57472       ['re_lu_153[0][0]']
#
#  batch_normalization_154 (Batch  (None, 4, 4, 128)   512         ['conv2d_156[0][0]']
#  Normalization)
#
#  dropout_34 (Dropout)           (None, 4, 4, 128)    0           ['batch_normalization_154[0][0]']
#
#  re_lu_154 (ReLU)               (None, 4, 4, 128)    0           ['dropout_34[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 4, 4, 32)     36896       ['re_lu_154[0][0]']
#
#  concatenate_74 (Concatenate)   (None, 4, 4, 480)    0           ['concatenate_73[0][0]',
#                                                                   'conv2d_157[0][0]']
#
#  batch_normalization_155 (Batch  (None, 4, 4, 480)   1920        ['concatenate_74[0][0]']
#  Normalization)
#
#  dropout_35 (Dropout)           (None, 4, 4, 480)    0           ['batch_normalization_155[0][0]']
#
#  re_lu_155 (ReLU)               (None, 4, 4, 480)    0           ['dropout_35[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 4, 4, 128)    61568       ['re_lu_155[0][0]']
#
#  batch_normalization_156 (Batch  (None, 4, 4, 128)   512         ['conv2d_158[0][0]']
#  Normalization)
#
#  dropout_36 (Dropout)           (None, 4, 4, 128)    0           ['batch_normalization_156[0][0]']
#
#  re_lu_156 (ReLU)               (None, 4, 4, 128)    0           ['dropout_36[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 4, 4, 32)     36896       ['re_lu_156[0][0]']
#
#  concatenate_75 (Concatenate)   (None, 4, 4, 512)    0           ['concatenate_74[0][0]',
#                                                                   'conv2d_159[0][0]']
#
#  batch_normalization_157 (Batch  (None, 4, 4, 512)   2048        ['concatenate_75[0][0]']
#  Normalization)
#
#  dropout_37 (Dropout)           (None, 4, 4, 512)    0           ['batch_normalization_157[0][0]']
#
#  re_lu_157 (ReLU)               (None, 4, 4, 512)    0           ['dropout_37[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 4, 4, 256)    131328      ['re_lu_157[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 2, 2, 256)   0           ['conv2d_160[0][0]']
#  oling2D)
#
#  batch_normalization_158 (Batch  (None, 2, 2, 256)   1024        ['average_pooling2d_5[0][0]']
#  Normalization)
#
#  dropout_38 (Dropout)           (None, 2, 2, 256)    0           ['batch_normalization_158[0][0]']
#
#  re_lu_158 (ReLU)               (None, 2, 2, 256)    0           ['dropout_38[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 2, 2, 128)    32896       ['re_lu_158[0][0]']
#
#  batch_normalization_159 (Batch  (None, 2, 2, 128)   512         ['conv2d_161[0][0]']
#  Normalization)
#
#  dropout_39 (Dropout)           (None, 2, 2, 128)    0           ['batch_normalization_159[0][0]']
#
#  re_lu_159 (ReLU)               (None, 2, 2, 128)    0           ['dropout_39[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 2, 2, 32)     36896       ['re_lu_159[0][0]']
#
#  concatenate_76 (Concatenate)   (None, 2, 2, 288)    0           ['average_pooling2d_5[0][0]',
#                                                                   'conv2d_162[0][0]']
#
#  batch_normalization_160 (Batch  (None, 2, 2, 288)   1152        ['concatenate_76[0][0]']
#  Normalization)
#
#  dropout_40 (Dropout)           (None, 2, 2, 288)    0           ['batch_normalization_160[0][0]']
#
#  re_lu_160 (ReLU)               (None, 2, 2, 288)    0           ['dropout_40[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 2, 2, 128)    36992       ['re_lu_160[0][0]']
#
#  batch_normalization_161 (Batch  (None, 2, 2, 128)   512         ['conv2d_163[0][0]']
#  Normalization)
#
#  dropout_41 (Dropout)           (None, 2, 2, 128)    0           ['batch_normalization_161[0][0]']
#
#  re_lu_161 (ReLU)               (None, 2, 2, 128)    0           ['dropout_41[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 2, 2, 32)     36896       ['re_lu_161[0][0]']
#
#  concatenate_77 (Concatenate)   (None, 2, 2, 320)    0           ['concatenate_76[0][0]',
#                                                                   'conv2d_164[0][0]']
#
#  batch_normalization_162 (Batch  (None, 2, 2, 320)   1280        ['concatenate_77[0][0]']
#  Normalization)
#
#  dropout_42 (Dropout)           (None, 2, 2, 320)    0           ['batch_normalization_162[0][0]']
#
#  re_lu_162 (ReLU)               (None, 2, 2, 320)    0           ['dropout_42[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 2, 2, 128)    41088       ['re_lu_162[0][0]']
#
#  batch_normalization_163 (Batch  (None, 2, 2, 128)   512         ['conv2d_165[0][0]']
#  Normalization)
#
#  dropout_43 (Dropout)           (None, 2, 2, 128)    0           ['batch_normalization_163[0][0]']
#
#  re_lu_163 (ReLU)               (None, 2, 2, 128)    0           ['dropout_43[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 2, 2, 32)     36896       ['re_lu_163[0][0]']
#
#  concatenate_78 (Concatenate)   (None, 2, 2, 352)    0           ['concatenate_77[0][0]',
#                                                                   'conv2d_166[0][0]']
#
#  batch_normalization_164 (Batch  (None, 2, 2, 352)   1408        ['concatenate_78[0][0]']
#  Normalization)
#
#  dropout_44 (Dropout)           (None, 2, 2, 352)    0           ['batch_normalization_164[0][0]']
#
#  re_lu_164 (ReLU)               (None, 2, 2, 352)    0           ['dropout_44[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 2, 2, 128)    45184       ['re_lu_164[0][0]']
#
#  batch_normalization_165 (Batch  (None, 2, 2, 128)   512         ['conv2d_167[0][0]']
# ...
#  conv2d_227 (Conv2D)            (None, 1, 1, 32)     36896       ['re_lu_224[0][0]']
#
#  concatenate_108 (Concatenate)  (None, 1, 1, 800)    0           ['concatenate_107[0][0]',
#                                                                   'conv2d_227[0][0]']
#
#  batch_normalization_225 (Batch  (None, 1, 1, 800)   3200        ['concatenate_108[0][0]']
#  Normalization)
#
#  dropout_105 (Dropout)          (None, 1, 1, 800)    0           ['batch_normalization_225[0][0]']
#
#  re_lu_225 (ReLU)               (None, 1, 1, 800)    0           ['dropout_105[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 1, 1, 128)    102528      ['re_lu_225[0][0]']
#
#  batch_normalization_226 (Batch  (None, 1, 1, 128)   512         ['conv2d_228[0][0]']
#  Normalization)
#
#  dropout_106 (Dropout)          (None, 1, 1, 128)    0           ['batch_normalization_226[0][0]']
#
#  re_lu_226 (ReLU)               (None, 1, 1, 128)    0           ['dropout_106[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 1, 1, 32)     36896       ['re_lu_226[0][0]']
#
#  concatenate_109 (Concatenate)  (None, 1, 1, 832)    0           ['concatenate_108[0][0]',
#                                                                   'conv2d_229[0][0]']
#
#  batch_normalization_227 (Batch  (None, 1, 1, 832)   3328        ['concatenate_109[0][0]']
#  Normalization)
#
#  dropout_107 (Dropout)          (None, 1, 1, 832)    0           ['batch_normalization_227[0][0]']
#
#  re_lu_227 (ReLU)               (None, 1, 1, 832)    0           ['dropout_107[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 1, 1, 128)    106624      ['re_lu_227[0][0]']
#
#  batch_normalization_228 (Batch  (None, 1, 1, 128)   512         ['conv2d_230[0][0]']
#  Normalization)
#
#  dropout_108 (Dropout)          (None, 1, 1, 128)    0           ['batch_normalization_228[0][0]']
#
#  re_lu_228 (ReLU)               (None, 1, 1, 128)    0           ['dropout_108[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 1, 1, 32)     36896       ['re_lu_228[0][0]']
#
#  concatenate_110 (Concatenate)  (None, 1, 1, 864)    0           ['concatenate_109[0][0]',
#                                                                   'conv2d_231[0][0]']
#
#  batch_normalization_229 (Batch  (None, 1, 1, 864)   3456        ['concatenate_110[0][0]']
#  Normalization)
#
#  dropout_109 (Dropout)          (None, 1, 1, 864)    0           ['batch_normalization_229[0][0]']
#
#  re_lu_229 (ReLU)               (None, 1, 1, 864)    0           ['dropout_109[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 1, 1, 128)    110720      ['re_lu_229[0][0]']
#
#  batch_normalization_230 (Batch  (None, 1, 1, 128)   512         ['conv2d_232[0][0]']
#  Normalization)
#
#  dropout_110 (Dropout)          (None, 1, 1, 128)    0           ['batch_normalization_230[0][0]']
#
#  re_lu_230 (ReLU)               (None, 1, 1, 128)    0           ['dropout_110[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 1, 1, 32)     36896       ['re_lu_230[0][0]']
#
#  concatenate_111 (Concatenate)  (None, 1, 1, 896)    0           ['concatenate_110[0][0]',
#                                                                   'conv2d_233[0][0]']
#
#  batch_normalization_231 (Batch  (None, 1, 1, 896)   3584        ['concatenate_111[0][0]']
#  Normalization)
#
#  dropout_111 (Dropout)          (None, 1, 1, 896)    0           ['batch_normalization_231[0][0]']
#
#  re_lu_231 (ReLU)               (None, 1, 1, 896)    0           ['dropout_111[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 1, 1, 128)    114816      ['re_lu_231[0][0]']
#
#  batch_normalization_232 (Batch  (None, 1, 1, 128)   512         ['conv2d_234[0][0]']
#  Normalization)
#
#  dropout_112 (Dropout)          (None, 1, 1, 128)    0           ['batch_normalization_232[0][0]']
#
#  re_lu_232 (ReLU)               (None, 1, 1, 128)    0           ['dropout_112[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 1, 1, 32)     36896       ['re_lu_232[0][0]']
#
#  concatenate_112 (Concatenate)  (None, 1, 1, 928)    0           ['concatenate_111[0][0]',
#                                                                   'conv2d_235[0][0]']
#
#  batch_normalization_233 (Batch  (None, 1, 1, 928)   3712        ['concatenate_112[0][0]']
#  Normalization)
#
#  dropout_113 (Dropout)          (None, 1, 1, 928)    0           ['batch_normalization_233[0][0]']
#
#  re_lu_233 (ReLU)               (None, 1, 1, 928)    0           ['dropout_113[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 1, 1, 128)    118912      ['re_lu_233[0][0]']
#
#  batch_normalization_234 (Batch  (None, 1, 1, 128)   512         ['conv2d_236[0][0]']
#  Normalization)
#
#  dropout_114 (Dropout)          (None, 1, 1, 128)    0           ['batch_normalization_234[0][0]']
#
#  re_lu_234 (ReLU)               (None, 1, 1, 128)    0           ['dropout_114[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 1, 1, 32)     36896       ['re_lu_234[0][0]']
#
#  concatenate_113 (Concatenate)  (None, 1, 1, 960)    0           ['concatenate_112[0][0]',
#                                                                   'conv2d_237[0][0]']
#
#  batch_normalization_235 (Batch  (None, 1, 1, 960)   3840        ['concatenate_113[0][0]']
#  Normalization)
#
#  dropout_115 (Dropout)          (None, 1, 1, 960)    0           ['batch_normalization_235[0][0]']
#
#  re_lu_235 (ReLU)               (None, 1, 1, 960)    0           ['dropout_115[0][0]']
#
#  conv2d_238 (Conv2D)            (None, 1, 1, 128)    123008      ['re_lu_235[0][0]']
#
#  batch_normalization_236 (Batch  (None, 1, 1, 128)   512         ['conv2d_238[0][0]']
#  Normalization)
#
#  dropout_116 (Dropout)          (None, 1, 1, 128)    0           ['batch_normalization_236[0][0]']
#
#  re_lu_236 (ReLU)               (None, 1, 1, 128)    0           ['dropout_116[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 1, 1, 32)     36896       ['re_lu_236[0][0]']
#
#  concatenate_114 (Concatenate)  (None, 1, 1, 992)    0           ['concatenate_113[0][0]',
#                                                                   'conv2d_239[0][0]']
#
#  batch_normalization_237 (Batch  (None, 1, 1, 992)   3968        ['concatenate_114[0][0]']
#  Normalization)
#
#  dropout_117 (Dropout)          (None, 1, 1, 992)    0           ['batch_normalization_237[0][0]']
#
#  re_lu_237 (ReLU)               (None, 1, 1, 992)    0           ['dropout_117[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 1, 1, 128)    127104      ['re_lu_237[0][0]']
#
#  batch_normalization_238 (Batch  (None, 1, 1, 128)   512         ['conv2d_240[0][0]']
#  Normalization)
#
#  dropout_118 (Dropout)          (None, 1, 1, 128)    0           ['batch_normalization_238[0][0]']
#
#  re_lu_238 (ReLU)               (None, 1, 1, 128)    0           ['dropout_118[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 1, 1, 32)     36896       ['re_lu_238[0][0]']
#
#  concatenate_115 (Concatenate)  (None, 1, 1, 1024)   0           ['concatenate_114[0][0]',
#                                                                   'conv2d_241[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1024)        0           ['concatenate_115[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 10)           10250       ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 7,053,642
# Trainable params: 6,972,170
# Non-trainable params: 81,472
# __________________________________________________________________________________________________

# %%
from livelossplot import PlotLossesKeras
import time 

start = time.time() 
model_history = model.fit(train_dataset, validation_data=val_dataset, epochs=300, callbacks=[PlotLossesKeras()], verbose=False)
end = time.time() - start 
print("Время: "+ str(end) +' секунд')
# Out:
# accuracy
# 	training         	 (min:    0.175, max:    0.743, cur:    0.743)
# 	validation       	 (min:    0.192, max:    0.777, cur:    0.767)
# Loss
# 	training         	 (min:    0.787, max:    2.471, cur:    0.787)
# 	validation       	 (min:    0.692, max:    9.286, cur:    0.833)

# %%
model.save("my_model")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 21). These functions will not be directly callable after loading.

# %%
import numpy as np 

# Приводим в единный массив из двойного (может есть оптимальней)
predictions = model.predict(x_test)
new_predictions = []
for i in predictions:
  i = list(i)
  max_i = max(i)
  index_max_i = i.index(max_i)
  new_predictions.append(index_max_i)
# Out:
# 782/782 [==============================] - 11s 13ms/step

# %%
import pandas as pd   #  pip install pandas

columns=['Id', 'Category']

data = []
data.append(np.arange(len(new_predictions)))
data.append(new_predictions)
data = np.array(data).T
df = pd.DataFrame(data, columns=columns)
df['Id'] = df['Id'].astype(int)

df.to_csv('/content/cartridge_accounting_RES50_1.csv', index= False )
