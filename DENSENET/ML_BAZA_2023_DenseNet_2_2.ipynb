# %% [markdown]
# **ДЛЯ ТЕХ КТО НА COLAB** ,следующие 2 бокса
#
# Шаг 2: Загрузка учетных данных API
# Чтобы загрузить данные из Kaggle, необходимо пройти аутентификацию в сервисах Kaggle. Для этого понадобится API-токен. Его можно сгенерировать в разделе профиля учетной записи пользователя Kaggle.
#
# Сначала перейдите в свой профиль Kaggle:
#
#
# Теперь откройте вкладку “Account” (“Аккаунт”) и опуститесь до раздела “API” (скриншот из профиля Kaggle).
#
# Будет загружен файл с именем “kaggle.json”, который содержит имя пользователя и ключ API.
#
# Это одноразовый шаг, так что вам не придется генерировать учетные данные всякий раз при загрузке набора данных.
#
# https://medium.com/nuances-of-programming/%D0%BA%D0%B0%D0%BA-%D0%B8%D0%BC%D0%BF%D0%BE%D1%80%D1%82%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D1%82%D1%8C-%D0%BD%D0%B0%D0%B1%D0%BE%D1%80%D1%8B-%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85-kaggle-%D0%B2-google-colab-51de3fd5a9a8#:~:text=%D0%97%D0%B0%D0%BF%D1%83%D1%81%D1%82%D0%B8%D1%82%D0%B5%20%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%20Google%20Colab%20%D0%B8,%D0%BD%D0%B5%D0%BE%D0%B1%D1%85%D0%BE%D0%B4%D0%B8%D0%BC%D1%8B%D1%85%20%D0%B4%D0%BB%D1%8F%20%D0%B7%D0%B0%D0%B3%D1%80%D1%83%D0%B7%D0%BA%D0%B8%20%D0%BD%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85

# %%
# https://medium.com/nuances-of-programming/%D0%BA%D0%B0%D0%BA-%D0%B8%D0%BC%D0%BF%D0%BE%D1%80%D1%82%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D1%82%D1%8C-%D0%BD%D0%B0%D0%B1%D0%BE%D1%80%D1%8B-%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85-kaggle-%D0%B2-google-colab-51de3fd5a9a8#:~:text=%D0%97%D0%B0%D0%BF%D1%83%D1%81%D1%82%D0%B8%D1%82%D0%B5%20%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%20Google%20Colab%20%D0%B8,%D0%BD%D0%B5%D0%BE%D0%B1%D1%85%D0%BE%D0%B4%D0%B8%D0%BC%D1%8B%D1%85%20%D0%B4%D0%BB%D1%8F%20%D0%B7%D0%B0%D0%B3%D1%80%D1%83%D0%B7%D0%BA%D0%B8%20%D0%BD%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85.
# Как импортировать наборы данных Kaggle в Google Colab?
# Сделать ШАГ 2 
# Также есть Лайфхак 2: Загрузка учетных данных Kaggle из Google Drive , чтобы каждый раз загружать kaggle.json
! mkdir ~/.kaggle

! cp kaggle.json ~/.kaggle/

! chmod 600 ~/.kaggle/kaggle.json

! kaggle competitions download ml-intensive-of-yandex-academy-2023 #Но аккаунт должен быть зарегистрирован на соревновании
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# Downloading ml-intensive-of-yandex-academy-2023.zip to /content
#  94% 246M/263M [00:01<00:00, 184MB/s]
# 100% 263M/263M [00:01<00:00, 139MB/s]

# %% [markdown]
# https://ru.stackoverflow.com/questions/1061024/%D0%94%D0%BE%D1%81%D1%82%D1%83%D0%BF-%D0%BA-%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0%D0%BC-zip-%D0%B0%D1%80%D1%85%D0%B8%D0%B2%D0%B0-%D0%B2-google-colab

# %%
# https://ru.stackoverflow.com/questions/1061024/%D0%94%D0%BE%D1%81%D1%82%D1%83%D0%BF-%D0%BA-%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0%D0%BC-zip-%D0%B0%D1%80%D1%85%D0%B8%D0%B2%D0%B0-%D0%B2-google-colab
# Доступ к папкам ZIP-архива в Google Colab
import zipfile
import os

data_r = zipfile.ZipFile('ml-intensive-of-yandex-academy-2023.zip', 'r')
data_r.printdir()
data_r.extractall()
# Out:
# File Name                                             Modified             Size
# data_test                                      2023-04-04 08:27:46    307200197
# data_train                                     2023-04-04 08:28:10    614450277
# meta                                           2023-04-04 08:29:00           73

# %% [markdown]
# **ОТСЮДА УЖЕ ДЛЯ ВСЕХ**

# %%
# http://cs.mipt.ru/advanced_python/lessons/lab13.html
# Теперь в отдельной программе выполним десериализацию. Это уже надо всем делать.
import pickle

# Data_train
with open('data_train', 'rb') as f:
    data_train = pickle.load(f)
print(data_train)
# Data_test
with open('data_test', 'rb') as f:
    data_test = pickle.load(f)
print(data_test)
# Out:
# {'section': 'train', 'labels': array([1, 3, 2, ..., 7, 5, 8], dtype=uint8), 'images': array([[[[ 21.,  27.,  49.],
#          [ 18.,  20.,  44.],
#          [ 13.,  13.,  41.],
#          ...,
#          [  0.,   4.,   6.],
#          [  0.,   4.,   4.],
#          [  0.,   4.,   3.]],
#
#         [[ 28.,  36.,  56.],
#          [ 26.,  32.,  56.],
#          [ 21.,  25.,  52.],
#          ...,
#          [  1.,   5.,   8.],
#          [  0.,   4.,   4.],
#          [  0.,   3.,   2.]],
#
#         [[ 55.,  64.,  80.],
#          [ 54.,  61.,  81.],
#          [ 48.,  54.,  77.],
#          ...,
#          [  1.,   5.,   8.],
#          [  0.,   4.,   5.],
#          [  1.,   5.,   4.]],
#
#         ...,
#
#         [[ 55.,  47.,  57.],
#          [ 36.,  31.,  40.],
#          [ 19.,  16.,  24.],
#          ...,
#          [  7.,   8.,   8.],
#          [  7.,   9.,   8.],
#          [  7.,   8.,   8.]],
#
#         [[ 18.,   8.,  22.],
#          [ 14.,   7.,  20.],
#          [  8.,   4.,  14.],
#          ...,
#          [  8.,   8.,   7.],
#          [  8.,   8.,   8.],
#          [  7.,   7.,   7.]],
#
#         [[ 13.,   5.,  20.],
#          [ 14.,   7.,  20.],
#          [ 15.,  11.,  21.],
#          ...,
#          [  9.,   9.,   9.],
#          [  8.,   8.,   8.],
#          [  8.,   8.,   8.]]],
#
#
#        [[[ 10.,  19.,  18.],
#          [ 13.,  21.,  20.],
#          [ 17.,  23.,  23.],
#          ...,
#          [ 63.,  72.,  59.],
#          [ 66.,  73.,  60.],
#          [ 66.,  72.,  59.]],
#
#         [[ 12.,  19.,  19.],
#          [ 14.,  21.,  20.],
#          [ 17.,  23.,  22.],
#          ...,
#          [255., 255., 255.],
#          [ 69.,  74.,  57.],
#          [ 67.,  72.,  55.]],
#
#         [[ 14.,  20.,  20.],
#          [ 15.,  21.,  20.],
#          [ 17.,  23.,  21.],
#          ...,
#          [ 74.,  79.,  56.],
#          [ 70.,  74.,  51.],
#          [ 67.,  69.,  46.]],
#
#         ...,
#
#         [[  0.,   1.,   5.],
#          [  1.,   1.,   5.],
#          [  2.,   1.,   6.],
#          ...,
#          [ 18.,  13.,   7.],
#          [ 23.,  17.,  11.],
#          [ 28.,  20.,  13.]],
#
#         [[  0.,   0.,   3.],
#          [  0.,   0.,   3.],
#          [  1.,   1.,   4.],
#          ...,
#          [ 16.,  12.,   7.],
#          [ 18.,  13.,   9.],
#          [ 20.,  14.,  10.]],
#
#         [[  0.,   0.,   2.],
#          [  0.,   0.,   2.],
#          [255., 255., 255.],
#          ...,
#          [ 15.,  12.,   7.],
#          [ 16.,  12.,   8.],
#          [ 16.,  12.,   8.]]],
#
#
#        [[[210., 212., 209.],
#          [  0.,   0.,   0.],
#          [210., 212., 209.],
#          ...,
#          [191., 191., 189.],
#          [194., 194., 192.],
#          [194., 194., 192.]],
#
#         [[209., 211., 208.],
#          [206., 208., 205.],
#          [204., 206., 203.],
#          ...,
#          [158., 156., 157.],
#          [163., 161., 162.],
#          [168., 166., 167.]],
#
#         [[205., 207., 204.],
#          [203., 205., 202.],
#          [200., 202., 199.],
#          ...,
#          [  0.,   0.,   0.],
#          [144., 141., 142.],
#          [151., 148., 149.]],
#
#         ...,
#
#         [[215., 215., 215.],
#          [214., 214., 214.],
#          [212., 212., 212.],
#          ...,
#          [201., 202., 202.],
#          [202., 203., 203.],
#          [205., 206., 206.]],
#
#         [[  0.,   0.,   0.],
#          [216., 216., 216.],
#          [215., 215., 215.],
#          ...,
#          [205., 207., 206.],
#          [206., 208., 207.],
#          [  0.,   0.,   0.]],
#
#         [[221., 221., 219.],
#          [219., 219., 217.],
#          [218., 218., 218.],
#          ...,
#          [203., 205., 202.],
#          [203., 205., 203.],
#          [  0.,   0.,   0.]]],
#
#
#        ...,
#
#
#        [[[157., 155., 143.],
#          [155., 152., 140.],
#          [155., 151., 139.],
#          ...,
#          [122., 135., 143.],
#          [103., 115., 118.],
#          [ 94., 106., 106.]],
#
#         [[160., 158., 146.],
#          [157., 154., 142.],
#          [155., 151., 139.],
#          ...,
#          [146., 160., 166.],
#          [118., 132., 133.],
#          [100., 112., 111.]],
#
#         [[164., 161., 149.],
#          [160., 156., 144.],
#          [157., 153., 141.],
#          ...,
#          [175., 188., 193.],
#          [141., 154., 154.],
#          [113., 124., 121.]],
#
#         ...,
#
#         [[171., 168., 158.],
#          [170., 167., 156.],
#          [164., 162., 149.],
#          ...,
#          [128., 127., 134.],
#          [123., 124., 128.],
#          [122., 123., 128.]],
#
#         [[175., 171., 163.],
#          [176., 171., 161.],
#          [169., 164., 152.],
#          ...,
#          [105., 107., 114.],
#          [104., 108., 113.],
#          [108., 111., 116.]],
#
#         [[178., 173., 167.],
#          [182., 175., 167.],
#          [176., 169., 159.],
#          ...,
#          [109., 113., 123.],
#          [112., 117., 125.],
#          [118., 125., 130.]]],
#
#
#        [[[ 75.,  62.,  54.],
#          [  0.,   0.,   0.],
#          [ 67.,  57.,  47.],
#          ...,
#          [ 82.,  71.,  67.],
#          [ 82.,  71.,  65.],
#          [  0.,   0.,   0.]],
#
#         [[ 95.,  85.,  73.],
#          [ 93.,  83.,  71.],
#          [ 90.,  81.,  66.],
#          ...,
#          [111.,  99.,  94.],
#          [112., 102.,  93.],
#          [112., 102.,  92.]],
#
#         [[119., 111.,  95.],
#          [117., 109.,  93.],
#          [255., 255., 255.],
#          ...,
#          [137., 124., 118.],
#          [135., 125., 116.],
#          [134., 124., 112.]],
#
#         ...,
#
#         [[ 87.,  84.,  67.],
#          [ 86.,  83.,  66.],
#          [ 87.,  84.,  65.],
#          ...,
#          [  0.,   0.,   0.],
#          [ 91.,  82.,  77.],
#          [ 93.,  84.,  79.]],
#
#         [[110., 105.,  86.],
#          [108., 103.,  84.],
#          [109., 104.,  85.],
#          ...,
#          [106.,  95.,  90.],
#          [107.,  97.,  89.],
#          [109.,  99.,  91.]],
#
#         [[124., 119.,  99.],
#          [125., 120., 101.],
#          [125., 120., 100.],
#          ...,
#          [120., 110.,  98.],
#          [123., 111.,  99.],
#          [255., 255., 255.]]],
#
#
#        [[[163., 178., 171.],
#          [169., 185., 175.],
#          [177., 193., 182.],
#          ...,
#          [ 88.,  73.,  65.],
#          [100.,  83.,  75.],
#          [108.,  88.,  77.]],
#
#         [[172., 190., 176.],
#          [175., 193., 177.],
#          [179., 196., 181.],
#          ...,
#          [ 91.,  73.,  69.],
#          [ 97.,  78.,  70.],
#          [104.,  84.,  73.]],
#
#         [[183., 204., 185.],
#          [187., 205., 189.],
#          [189., 207., 191.],
#          ...,
#          [ 92.,  74.,  71.],
#          [ 97.,  80.,  71.],
#          [104.,  86.,  72.]],
#
#         ...,
#
#         [[189., 194., 186.],
#          [190., 193., 183.],
#          [174., 177., 165.],
#          ...,
#          [ 96.,  76.,  74.],
#          [ 87.,  66.,  66.],
#          [ 91.,  69.,  73.]],
#
#         [[255., 255., 255.],
#          [  0.,   0.,   0.],
#          [182., 186., 168.],
#          ...,
#          [ 84.,  64.,  70.],
#          [ 77.,  56.,  64.],
#          [  0.,   0.,   0.]],
#
#         [[189., 196., 178.],
#          [194., 199., 179.],
#          [188., 193., 171.],
#          ...,
#          [ 76.,  59.,  65.],
#          [ 69.,  52.,  61.],
#          [ 82.,  62.,  73.]]]], dtype=float32)}
# {'section': 'test', 'images': array([[[[ 67.,  73.,  87.],
#          [ 74.,  78.,  92.],
#          [ 76.,  78.,  94.],
#          ...,
#          [ 57.,  64.,  81.],
#          [ 54.,  61.,  77.],
#          [ 49.,  56.,  72.]],
#
#         [[ 68.,  74.,  88.],
#          [ 72.,  76.,  92.],
#          [ 73.,  75.,  93.],
#          ...,
#          [ 66.,  75.,  89.],
#          [ 65.,  72.,  88.],
#          [ 61.,  69.,  84.]],
#
#         [[ 68.,  74.,  88.],
#          [ 70.,  74.,  90.],
#          [255., 255., 255.],
#          ...,
#          [ 85.,  91., 101.],
#          [ 86.,  91., 101.],
#          [ 84.,  89.,  99.]],
#
#         ...,
#
#         [[ 60.,  73.,  86.],
#          [ 57.,  69.,  84.],
#          [255., 255., 255.],
#          ...,
#          [ 81.,  87.,  97.],
#          [ 82.,  90.,  98.],
#          [ 83.,  90.,  96.]],
#
#         [[ 58.,  70.,  84.],
#          [ 52.,  64.,  79.],
#          [ 48.,  59.,  76.],
#          ...,
#          [ 71.,  76.,  90.],
#          [ 72.,  79.,  89.],
#          [ 73.,  80.,  87.]],
#
#         [[ 57.,  69.,  83.],
#          [ 50.,  62.,  78.],
#          [ 45.,  57.,  73.],
#          ...,
#          [ 60.,  64.,  81.],
#          [ 61.,  68.,  80.],
#          [ 63.,  70.,  81.]]],
#
#
#        [[[ 63.,  63.,  55.],
#          [ 63.,  63.,  54.],
#          [ 63.,  63.,  53.],
#          ...,
#          [ 74.,  70.,  66.],
#          [ 78.,  73.,  70.],
#          [ 81.,  77.,  74.]],
#
#         [[ 64.,  65.,  57.],
#          [ 64.,  64.,  56.],
#          [ 64.,  64.,  55.],
#          ...,
#          [ 77.,  70.,  67.],
#          [ 79.,  73.,  71.],
#          [255., 255., 255.]],
#
#         [[ 65.,  64.,  56.],
#          [255., 255., 255.],
#          [ 64.,  64.,  56.],
#          ...,
#          [ 68.,  58.,  57.],
#          [ 76.,  67.,  66.],
#          [  0.,   0.,   0.]],
#
#         ...,
#
#         [[ 80.,  73.,  80.],
#          [ 80.,  75.,  81.],
#          [ 82.,  77.,  83.],
#          ...,
#          [106., 105., 110.],
#          [109., 108., 114.],
#          [109., 109., 116.]],
#
#         [[ 79.,  72.,  79.],
#          [ 80.,  74.,  81.],
#          [ 82.,  77.,  83.],
#          ...,
#          [106., 106., 111.],
#          [108., 109., 115.],
#          [108., 109., 118.]],
#
#         [[255., 255., 255.],
#          [ 79.,  73.,  81.],
#          [ 81.,  76.,  83.],
#          ...,
#          [107., 107., 112.],
#          [108., 110., 116.],
#          [107., 110., 119.]]],
#
#
#        [[[141., 153., 175.],
#          [127., 138., 162.],
#          [  0.,   0.,   0.],
#          ...,
#          [  0.,   0.,   0.],
#          [131., 162., 177.],
#          [146., 176., 187.]],
#
#         [[137., 149., 172.],
#          [124., 135., 160.],
#          [255., 255., 255.],
#          ...,
#          [105., 140., 159.],
#          [255., 255., 255.],
#          [  0.,   0.,   0.]],
#
#         [[129., 141., 166.],
#          [119., 129., 155.],
#          [113., 123., 149.],
#          ...,
#          [101., 137., 157.],
#          [129., 164., 181.],
#          [146., 179., 193.]],
#
#         ...,
#
#         [[156., 172., 192.],
#          [145., 161., 181.],
#          [135., 151., 172.],
#          ...,
#          [  0.,   0.,   0.],
#          [172., 190., 199.],
#          [172., 190., 198.]],
#
#         [[164., 178., 196.],
#          [158., 172., 190.],
#          [151., 165., 183.],
#          ...,
#          [175., 191., 197.],
#          [174., 191., 198.],
#          [175., 192., 199.]],
#
#         [[168., 180., 194.],
#          [165., 176., 190.],
#          [160., 171., 185.],
#          ...,
#          [  0.,   0.,   0.],
#          [176., 191., 198.],
#          [177., 192., 199.]]],
#
#
#        ...,
#
#
#        [[[203., 212., 219.],
#          [203., 211., 221.],
#          [204., 213., 224.],
#          ...,
#          [206., 217., 223.],
#          [206., 217., 223.],
#          [205., 216., 222.]],
#
#         [[199., 206., 215.],
#          [200., 207., 218.],
#          [202., 211., 223.],
#          ...,
#          [199., 212., 219.],
#          [203., 214., 222.],
#          [206., 218., 224.]],
#
#         [[197., 204., 215.],
#          [199., 206., 219.],
#          [199., 207., 222.],
#          ...,
#          [188., 203., 211.],
#          [197., 211., 219.],
#          [206., 220., 226.]],
#
#         ...,
#
#         [[202., 209., 218.],
#          [200., 209., 218.],
#          [197., 206., 216.],
#          ...,
#          [185., 195., 207.],
#          [196., 205., 216.],
#          [205., 214., 226.]],
#
#         [[200., 207., 215.],
#          [200., 208., 216.],
#          [200., 209., 217.],
#          ...,
#          [194., 206., 216.],
#          [204., 214., 224.],
#          [210., 221., 231.]],
#
#         [[198., 205., 213.],
#          [199., 208., 215.],
#          [200., 210., 216.],
#          ...,
#          [197., 211., 218.],
#          [205., 218., 226.],
#          [211., 224., 232.]]],
#
#
#        [[[133., 125., 123.],
#          [133., 125., 123.],
#          [132., 124., 122.],
#          ...,
#          [142., 127., 131.],
#          [143., 128., 131.],
#          [143., 128., 131.]],
#
#         [[126., 118., 116.],
#          [126., 118., 116.],
#          [126., 118., 116.],
#          ...,
#          [142., 127., 131.],
#          [143., 128., 131.],
#          [143., 128., 131.]],
#
#         [[110., 102., 100.],
#          [111., 103., 101.],
#          [113., 105., 103.],
#          ...,
#          [141., 126., 130.],
#          [  0.,   0.,   0.],
#          [144., 129., 132.]],
#
#         ...,
#
#         [[119., 110., 111.],
#          [121., 111., 113.],
#          [125., 114., 118.],
#          ...,
#          [153., 141., 143.],
#          [154., 142., 144.],
#          [154., 142., 144.]],
#
#         [[125., 114., 118.],
#          [126., 115., 119.],
#          [129., 118., 122.],
#          ...,
#          [153., 141., 143.],
#          [153., 141., 143.],
#          [  0.,   0.,   0.]],
#
#         [[127., 116., 120.],
#          [128., 117., 121.],
#          [131., 120., 124.],
#          ...,
#          [153., 141., 143.],
#          [153., 141., 143.],
#          [153., 141., 143.]]],
#
#
#        [[[ 81.,  74.,  66.],
#          [ 84.,  76.,  71.],
#          [ 91.,  83.,  82.],
#          ...,
#          [159., 131., 104.],
#          [159., 128.,  99.],
#          [  0.,   0.,   0.]],
#
#         [[  0.,   0.,   0.],
#          [ 84.,  76.,  72.],
#          [  0.,   0.,   0.],
#          ...,
#          [132., 108.,  84.],
#          [129., 103.,  76.],
#          [126.,  99.,  71.]],
#
#         [[ 88.,  79.,  72.],
#          [ 88.,  79.,  75.],
#          [ 90.,  83.,  82.],
#          ...,
#          [255., 255., 255.],
#          [103.,  81.,  62.],
#          [ 98.,  74.,  53.]],
#
#         ...,
#
#         [[121.,  94.,  82.],
#          [129., 101.,  92.],
#          [  0.,   0.,   0.],
#          ...,
#          [173., 178., 214.],
#          [173., 177., 208.],
#          [159., 165., 190.]],
#
#         [[122.,  94.,  82.],
#          [131., 102.,  92.],
#          [144., 115., 109.],
#          ...,
#          [145., 150., 188.],
#          [161., 165., 199.],
#          [159., 166., 194.]],
#
#         [[  0.,   0.,   0.],
#          [128., 100.,  88.],
#          [142., 114., 106.],
#          ...,
#          [255., 255., 255.],
#          [138., 144., 179.],
#          [149., 155., 188.]]]], dtype=float32)}

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline
from tensorflow.keras import layers

# %%
# ДАТАСЕТ
x_train_full = data_train['images']
y_train_full = data_train['labels']

x_test = data_test['images']
x_train_full, x_test = x_train_full / 255.0, x_test / 255.0

# %%
n_values = 10

# YOUR CODE HERE
y_train_full_one_hot = tf.one_hot(y_train_full, n_values)
# y_test_one_hot = tf.one_hot(test_images, n_values)

# %%
val_size = 0.1
batch_size = 256
size = x_train_full.shape[0]

x_val, y_val_one_hot = x_train_full[:int(size * 0.1)], y_train_full_one_hot[:int(size * 0.1)]
x_train, y_train_one_hot = x_train_full[int(size * 0.1):], y_train_full_one_hot[int(size * 0.1):]

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train_one_hot))
train_dataset = train_dataset.shuffle(1024)
train_dataset = train_dataset.batch(batch_size)

val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val_one_hot))
val_dataset = val_dataset.shuffle(1024)
val_dataset = val_dataset.batch(batch_size)

# %%
! pip install livelossplot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting livelossplot
#   Downloading livelossplot-0.5.5-py3-none-any.whl (22 kB)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.9/dist-packages (from livelossplot) (2.4.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from livelossplot) (3.7.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (1.22.4)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (3.1.2)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (6.2)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (8.4.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (4.5.0)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (23.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.9/dist-packages (from bokeh->livelossplot) (6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->livelossplot) (2.8.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->livelossplot) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=2.9->bokeh->livelossplot) (2.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->livelossplot) (1.16.0)
# Installing collected packages: livelossplot
# Successfully installed livelossplot-0.5.5

# %%
from tensorflow.keras import layers

#СОЗДАЕМ МОДЕЛЬ 
input_shape = x_train.shape[-3:]

import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, Conv3D, DepthwiseConv2D, SeparableConv2D, Conv3DTranspose
from keras.layers import Flatten, MaxPool2D, AvgPool2D, GlobalAvgPool2D, UpSampling2D, BatchNormalization
from keras.layers import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

from time import time
import numpy as np
     

import tensorflow as tf

def dense_block(x, blocks, name):
    for i in range(blocks):
        x1 = tf.keras.layers.BatchNormalization()(x)
        x1 = tf.keras.layers.Dropout(0.4)(x1)
        x1 = tf.keras.layers.ReLU()(x1)
        x1 = tf.keras.layers.Conv2D(12, 3, padding='same')(x1)
        x = tf.keras.layers.concatenate([x, x1], axis=-1, name=name+'_block'+str(i+1))
    return x

def transition_block(x, reduction, name):
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.4)(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.Conv2D(int(tf.keras.backend.int_shape(x)[-1] * reduction), 1, padding='same')(x)
    x = tf.keras.layers.AveragePooling2D(2, strides=2)(x)
    return x

def densenet(input_shape=(32,32,3), num_classes=10):
    inputs = tf.keras.layers.Input(shape=input_shape)
    x = tf.keras.layers.Conv2D(64, 3, strides=1, use_bias=False)(inputs)

    x = dense_block(x, 6, name='dense_block1')
    x = transition_block(x, 0.5, name='transition_block1')

    x = dense_block(x, 12, name='dense_block2')
    x = transition_block(x, 0.5, name='transition_block2')

    x = dense_block(x, 24, name='dense_block3')
    x = transition_block(x, 0.5, name='transition_block3')

    x = dense_block(x, 16, name='dense_block4')

    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.4)(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs, x, name='densenet')
    return model
model = densenet()

# Компиляция и обучение модели
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "densenet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_62 (Conv2D)             (None, 30, 30, 64)   1728        ['input_2[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 30, 30, 64)  256         ['conv2d_62[0][0]']
#  ormalization)
#
#  dropout_61 (Dropout)           (None, 30, 30, 64)   0           ['batch_normalization_62[0][0]']
#
#  re_lu_62 (ReLU)                (None, 30, 30, 64)   0           ['dropout_61[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 30, 30, 12)   6924        ['re_lu_62[0][0]']
#
#  dense_block1_block1 (Concatena  (None, 30, 30, 76)  0           ['conv2d_62[0][0]',
#  te)                                                              'conv2d_63[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 30, 30, 76)  304         ['dense_block1_block1[0][0]']
#  ormalization)
#
#  dropout_62 (Dropout)           (None, 30, 30, 76)   0           ['batch_normalization_63[0][0]']
#
#  re_lu_63 (ReLU)                (None, 30, 30, 76)   0           ['dropout_62[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 30, 30, 12)   8220        ['re_lu_63[0][0]']
#
#  dense_block1_block2 (Concatena  (None, 30, 30, 88)  0           ['dense_block1_block1[0][0]',
#  te)                                                              'conv2d_64[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 30, 30, 88)  352         ['dense_block1_block2[0][0]']
#  ormalization)
#
#  dropout_63 (Dropout)           (None, 30, 30, 88)   0           ['batch_normalization_64[0][0]']
#
#  re_lu_64 (ReLU)                (None, 30, 30, 88)   0           ['dropout_63[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 30, 30, 12)   9516        ['re_lu_64[0][0]']
#
#  dense_block1_block3 (Concatena  (None, 30, 30, 100)  0          ['dense_block1_block2[0][0]',
#  te)                                                              'conv2d_65[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 30, 30, 100)  400        ['dense_block1_block3[0][0]']
#  ormalization)
#
#  dropout_64 (Dropout)           (None, 30, 30, 100)  0           ['batch_normalization_65[0][0]']
#
#  re_lu_65 (ReLU)                (None, 30, 30, 100)  0           ['dropout_64[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 30, 30, 12)   10812       ['re_lu_65[0][0]']
#
#  dense_block1_block4 (Concatena  (None, 30, 30, 112)  0          ['dense_block1_block3[0][0]',
#  te)                                                              'conv2d_66[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 30, 30, 112)  448        ['dense_block1_block4[0][0]']
#  ormalization)
#
#  dropout_65 (Dropout)           (None, 30, 30, 112)  0           ['batch_normalization_66[0][0]']
#
#  re_lu_66 (ReLU)                (None, 30, 30, 112)  0           ['dropout_65[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 30, 30, 12)   12108       ['re_lu_66[0][0]']
#
#  dense_block1_block5 (Concatena  (None, 30, 30, 124)  0          ['dense_block1_block4[0][0]',
#  te)                                                              'conv2d_67[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 30, 30, 124)  496        ['dense_block1_block5[0][0]']
#  ormalization)
#
#  dropout_66 (Dropout)           (None, 30, 30, 124)  0           ['batch_normalization_67[0][0]']
#
#  re_lu_67 (ReLU)                (None, 30, 30, 124)  0           ['dropout_66[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 30, 30, 12)   13404       ['re_lu_67[0][0]']
#
#  dense_block1_block6 (Concatena  (None, 30, 30, 136)  0          ['dense_block1_block5[0][0]',
#  te)                                                              'conv2d_68[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 30, 30, 136)  544        ['dense_block1_block6[0][0]']
#  ormalization)
#
#  dropout_67 (Dropout)           (None, 30, 30, 136)  0           ['batch_normalization_68[0][0]']
#
#  re_lu_68 (ReLU)                (None, 30, 30, 136)  0           ['dropout_67[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 30, 30, 68)   9316        ['re_lu_68[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 15, 15, 68)  0           ['conv2d_69[0][0]']
#  oling2D)
#
#  batch_normalization_69 (BatchN  (None, 15, 15, 68)  272         ['average_pooling2d_3[0][0]']
#  ormalization)
#
#  dropout_68 (Dropout)           (None, 15, 15, 68)   0           ['batch_normalization_69[0][0]']
#
#  re_lu_69 (ReLU)                (None, 15, 15, 68)   0           ['dropout_68[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 15, 15, 12)   7356        ['re_lu_69[0][0]']
#
#  dense_block2_block1 (Concatena  (None, 15, 15, 80)  0           ['average_pooling2d_3[0][0]',
#  te)                                                              'conv2d_70[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 15, 15, 80)  320         ['dense_block2_block1[0][0]']
#  ormalization)
#
#  dropout_69 (Dropout)           (None, 15, 15, 80)   0           ['batch_normalization_70[0][0]']
#
#  re_lu_70 (ReLU)                (None, 15, 15, 80)   0           ['dropout_69[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 15, 15, 12)   8652        ['re_lu_70[0][0]']
#
#  dense_block2_block2 (Concatena  (None, 15, 15, 92)  0           ['dense_block2_block1[0][0]',
#  te)                                                              'conv2d_71[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 15, 15, 92)  368         ['dense_block2_block2[0][0]']
#  ormalization)
#
#  dropout_70 (Dropout)           (None, 15, 15, 92)   0           ['batch_normalization_71[0][0]']
#
#  re_lu_71 (ReLU)                (None, 15, 15, 92)   0           ['dropout_70[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 15, 15, 12)   9948        ['re_lu_71[0][0]']
#
#  dense_block2_block3 (Concatena  (None, 15, 15, 104)  0          ['dense_block2_block2[0][0]',
#  te)                                                              'conv2d_72[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 15, 15, 104)  416        ['dense_block2_block3[0][0]']
#  ormalization)
#
#  dropout_71 (Dropout)           (None, 15, 15, 104)  0           ['batch_normalization_72[0][0]']
#
#  re_lu_72 (ReLU)                (None, 15, 15, 104)  0           ['dropout_71[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 15, 15, 12)   11244       ['re_lu_72[0][0]']
#
#  dense_block2_block4 (Concatena  (None, 15, 15, 116)  0          ['dense_block2_block3[0][0]',
#  te)                                                              'conv2d_73[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 15, 15, 116)  464        ['dense_block2_block4[0][0]']
#  ormalization)
#
#  dropout_72 (Dropout)           (None, 15, 15, 116)  0           ['batch_normalization_73[0][0]']
#
#  re_lu_73 (ReLU)                (None, 15, 15, 116)  0           ['dropout_72[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 15, 15, 12)   12540       ['re_lu_73[0][0]']
#
#  dense_block2_block5 (Concatena  (None, 15, 15, 128)  0          ['dense_block2_block4[0][0]',
#  te)                                                              'conv2d_74[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 15, 15, 128)  512        ['dense_block2_block5[0][0]']
#  ormalization)
#
#  dropout_73 (Dropout)           (None, 15, 15, 128)  0           ['batch_normalization_74[0][0]']
#
#  re_lu_74 (ReLU)                (None, 15, 15, 128)  0           ['dropout_73[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 15, 15, 12)   13836       ['re_lu_74[0][0]']
#
#  dense_block2_block6 (Concatena  (None, 15, 15, 140)  0          ['dense_block2_block5[0][0]',
#  te)                                                              'conv2d_75[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 15, 15, 140)  560        ['dense_block2_block6[0][0]']
#  ormalization)
#
#  dropout_74 (Dropout)           (None, 15, 15, 140)  0           ['batch_normalization_75[0][0]']
#
#  re_lu_75 (ReLU)                (None, 15, 15, 140)  0           ['dropout_74[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 15, 15, 12)   15132       ['re_lu_75[0][0]']
#
#  dense_block2_block7 (Concatena  (None, 15, 15, 152)  0          ['dense_block2_block6[0][0]',
#  te)                                                              'conv2d_76[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 15, 15, 152)  608        ['dense_block2_block7[0][0]']
#  ormalization)
#
#  dropout_75 (Dropout)           (None, 15, 15, 152)  0           ['batch_normalization_76[0][0]']
#
#  re_lu_76 (ReLU)                (None, 15, 15, 152)  0           ['dropout_75[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 15, 15, 12)   16428       ['re_lu_76[0][0]']
#
#  dense_block2_block8 (Concatena  (None, 15, 15, 164)  0          ['dense_block2_block7[0][0]',
#  te)                                                              'conv2d_77[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 15, 15, 164)  656        ['dense_block2_block8[0][0]']
#  ormalization)
#
#  dropout_76 (Dropout)           (None, 15, 15, 164)  0           ['batch_normalization_77[0][0]']
#
#  re_lu_77 (ReLU)                (None, 15, 15, 164)  0           ['dropout_76[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 15, 15, 12)   17724       ['re_lu_77[0][0]']
#
#  dense_block2_block9 (Concatena  (None, 15, 15, 176)  0          ['dense_block2_block8[0][0]',
#  te)                                                              'conv2d_78[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 15, 15, 176)  704        ['dense_block2_block9[0][0]']
#  ormalization)
#
#  dropout_77 (Dropout)           (None, 15, 15, 176)  0           ['batch_normalization_78[0][0]']
#
#  re_lu_78 (ReLU)                (None, 15, 15, 176)  0           ['dropout_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 15, 15, 12)   19020       ['re_lu_78[0][0]']
#
#  dense_block2_block10 (Concaten  (None, 15, 15, 188)  0          ['dense_block2_block9[0][0]',
#  ate)                                                             'conv2d_79[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 15, 15, 188)  752        ['dense_block2_block10[0][0]']
#  ormalization)
#
#  dropout_78 (Dropout)           (None, 15, 15, 188)  0           ['batch_normalization_79[0][0]']
#
#  re_lu_79 (ReLU)                (None, 15, 15, 188)  0           ['dropout_78[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 15, 15, 12)   20316       ['re_lu_79[0][0]']
#
#  dense_block2_block11 (Concaten  (None, 15, 15, 200)  0          ['dense_block2_block10[0][0]',
#  ate)                                                             'conv2d_80[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 15, 15, 200)  800        ['dense_block2_block11[0][0]']
#  ormalization)
#
#  dropout_79 (Dropout)           (None, 15, 15, 200)  0           ['batch_normalization_80[0][0]']
#
#  re_lu_80 (ReLU)                (None, 15, 15, 200)  0           ['dropout_79[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 15, 15, 12)   21612       ['re_lu_80[0][0]']
#
#  dense_block2_block12 (Concaten  (None, 15, 15, 212)  0          ['dense_block2_block11[0][0]',
#  ate)                                                             'conv2d_81[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 15, 15, 212)  848        ['dense_block2_block12[0][0]']
#  ormalization)
#
#  dropout_80 (Dropout)           (None, 15, 15, 212)  0           ['batch_normalization_81[0][0]']
#
#  re_lu_81 (ReLU)                (None, 15, 15, 212)  0           ['dropout_80[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 15, 15, 106)  22578       ['re_lu_81[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 7, 7, 106)   0           ['conv2d_82[0][0]']
#  oling2D)
#
#  batch_normalization_82 (BatchN  (None, 7, 7, 106)   424         ['average_pooling2d_4[0][0]']
#  ormalization)
#
#  dropout_81 (Dropout)           (None, 7, 7, 106)    0           ['batch_normalization_82[0][0]']
#
#  re_lu_82 (ReLU)                (None, 7, 7, 106)    0           ['dropout_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 7, 7, 12)     11460       ['re_lu_82[0][0]']
#
#  dense_block3_block1 (Concatena  (None, 7, 7, 118)   0           ['average_pooling2d_4[0][0]',
#  te)                                                              'conv2d_83[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 7, 7, 118)   472         ['dense_block3_block1[0][0]']
#  ormalization)
#
#  dropout_82 (Dropout)           (None, 7, 7, 118)    0           ['batch_normalization_83[0][0]']
#
#  re_lu_83 (ReLU)                (None, 7, 7, 118)    0           ['dropout_82[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 7, 7, 12)     12756       ['re_lu_83[0][0]']
#
#  dense_block3_block2 (Concatena  (None, 7, 7, 130)   0           ['dense_block3_block1[0][0]',
#  te)                                                              'conv2d_84[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 7, 7, 130)   520         ['dense_block3_block2[0][0]']
#  ormalization)
#
#  dropout_83 (Dropout)           (None, 7, 7, 130)    0           ['batch_normalization_84[0][0]']
#
#  re_lu_84 (ReLU)                (None, 7, 7, 130)    0           ['dropout_83[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 7, 7, 12)     14052       ['re_lu_84[0][0]']
#
#  dense_block3_block3 (Concatena  (None, 7, 7, 142)   0           ['dense_block3_block2[0][0]',
#  te)                                                              'conv2d_85[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 7, 7, 142)   568         ['dense_block3_block3[0][0]']
#  ormalization)
#
#  dropout_84 (Dropout)           (None, 7, 7, 142)    0           ['batch_normalization_85[0][0]']
#
#  re_lu_85 (ReLU)                (None, 7, 7, 142)    0           ['dropout_84[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 7, 7, 12)     15348       ['re_lu_85[0][0]']
#
#  dense_block3_block4 (Concatena  (None, 7, 7, 154)   0           ['dense_block3_block3[0][0]',
#  te)                                                              'conv2d_86[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 7, 7, 154)   616         ['dense_block3_block4[0][0]']
#  ormalization)
#
#  dropout_85 (Dropout)           (None, 7, 7, 154)    0           ['batch_normalization_86[0][0]']
#
#  re_lu_86 (ReLU)                (None, 7, 7, 154)    0           ['dropout_85[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 7, 7, 12)     16644       ['re_lu_86[0][0]']
#
#  dense_block3_block5 (Concatena  (None, 7, 7, 166)   0           ['dense_block3_block4[0][0]',
#  te)                                                              'conv2d_87[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 7, 7, 166)   664         ['dense_block3_block5[0][0]']
#  ormalization)
#
#  dropout_86 (Dropout)           (None, 7, 7, 166)    0           ['batch_normalization_87[0][0]']
#
#  re_lu_87 (ReLU)                (None, 7, 7, 166)    0           ['dropout_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 7, 7, 12)     17940       ['re_lu_87[0][0]']
#
#  dense_block3_block6 (Concatena  (None, 7, 7, 178)   0           ['dense_block3_block5[0][0]',
#  te)                                                              'conv2d_88[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 7, 7, 178)   712         ['dense_block3_block6[0][0]']
#  ormalization)
#
#  dropout_87 (Dropout)           (None, 7, 7, 178)    0           ['batch_normalization_88[0][0]']
#
#  re_lu_88 (ReLU)                (None, 7, 7, 178)    0           ['dropout_87[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 7, 7, 12)     19236       ['re_lu_88[0][0]']
#
#  dense_block3_block7 (Concatena  (None, 7, 7, 190)   0           ['dense_block3_block6[0][0]',
#  te)                                                              'conv2d_89[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 7, 7, 190)   760         ['dense_block3_block7[0][0]']
#  ormalization)
#
#  dropout_88 (Dropout)           (None, 7, 7, 190)    0           ['batch_normalization_89[0][0]']
#
#  re_lu_89 (ReLU)                (None, 7, 7, 190)    0           ['dropout_88[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 7, 7, 12)     20532       ['re_lu_89[0][0]']
#
#  dense_block3_block8 (Concatena  (None, 7, 7, 202)   0           ['dense_block3_block7[0][0]',
#  te)                                                              'conv2d_90[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 7, 7, 202)   808         ['dense_block3_block8[0][0]']
#  ormalization)
#
#  dropout_89 (Dropout)           (None, 7, 7, 202)    0           ['batch_normalization_90[0][0]']
#
#  re_lu_90 (ReLU)                (None, 7, 7, 202)    0           ['dropout_89[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 7, 7, 12)     21828       ['re_lu_90[0][0]']
#
#  dense_block3_block9 (Concatena  (None, 7, 7, 214)   0           ['dense_block3_block8[0][0]',
#  te)                                                              'conv2d_91[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 7, 7, 214)   856         ['dense_block3_block9[0][0]']
#  ormalization)
#
#  dropout_90 (Dropout)           (None, 7, 7, 214)    0           ['batch_normalization_91[0][0]']
#
#  re_lu_91 (ReLU)                (None, 7, 7, 214)    0           ['dropout_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 7, 7, 12)     23124       ['re_lu_91[0][0]']
#
#  dense_block3_block10 (Concaten  (None, 7, 7, 226)   0           ['dense_block3_block9[0][0]',
#  ate)                                                             'conv2d_92[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 7, 7, 226)   904         ['dense_block3_block10[0][0]']
#  ormalization)
#
#  dropout_91 (Dropout)           (None, 7, 7, 226)    0           ['batch_normalization_92[0][0]']
#
#  re_lu_92 (ReLU)                (None, 7, 7, 226)    0           ['dropout_91[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 7, 7, 12)     24420       ['re_lu_92[0][0]']
#
#  dense_block3_block11 (Concaten  (None, 7, 7, 238)   0           ['dense_block3_block10[0][0]',
#  ate)                                                             'conv2d_93[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 7, 7, 238)   952         ['dense_block3_block11[0][0]']
#  ormalization)
#
#  dropout_92 (Dropout)           (None, 7, 7, 238)    0           ['batch_normalization_93[0][0]']
#
#  re_lu_93 (ReLU)                (None, 7, 7, 238)    0           ['dropout_92[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 7, 7, 12)     25716       ['re_lu_93[0][0]']
#
#  dense_block3_block12 (Concaten  (None, 7, 7, 250)   0           ['dense_block3_block11[0][0]',
#  ate)                                                             'conv2d_94[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 7, 7, 250)   1000        ['dense_block3_block12[0][0]']
#  ormalization)
#
#  dropout_93 (Dropout)           (None, 7, 7, 250)    0           ['batch_normalization_94[0][0]']
#
#  re_lu_94 (ReLU)                (None, 7, 7, 250)    0           ['dropout_93[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 7, 7, 12)     27012       ['re_lu_94[0][0]']
#
#  dense_block3_block13 (Concaten  (None, 7, 7, 262)   0           ['dense_block3_block12[0][0]',
#  ate)                                                             'conv2d_95[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 7, 7, 262)   1048        ['dense_block3_block13[0][0]']
#  ormalization)
#
#  dropout_94 (Dropout)           (None, 7, 7, 262)    0           ['batch_normalization_95[0][0]']
#
#  re_lu_95 (ReLU)                (None, 7, 7, 262)    0           ['dropout_94[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 7, 7, 12)     28308       ['re_lu_95[0][0]']
#
#  dense_block3_block14 (Concaten  (None, 7, 7, 274)   0           ['dense_block3_block13[0][0]',
#  ate)                                                             'conv2d_96[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 7, 7, 274)   1096        ['dense_block3_block14[0][0]']
#  ormalization)
#
#  dropout_95 (Dropout)           (None, 7, 7, 274)    0           ['batch_normalization_96[0][0]']
#
#  re_lu_96 (ReLU)                (None, 7, 7, 274)    0           ['dropout_95[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 7, 7, 12)     29604       ['re_lu_96[0][0]']
#
#  dense_block3_block15 (Concaten  (None, 7, 7, 286)   0           ['dense_block3_block14[0][0]',
#  ate)                                                             'conv2d_97[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 7, 7, 286)   1144        ['dense_block3_block15[0][0]']
#  ormalization)
#
#  dropout_96 (Dropout)           (None, 7, 7, 286)    0           ['batch_normalization_97[0][0]']
#
#  re_lu_97 (ReLU)                (None, 7, 7, 286)    0           ['dropout_96[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 7, 7, 12)     30900       ['re_lu_97[0][0]']
#
#  dense_block3_block16 (Concaten  (None, 7, 7, 298)   0           ['dense_block3_block15[0][0]',
#  ate)                                                             'conv2d_98[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 7, 7, 298)   1192        ['dense_block3_block16[0][0]']
#  ormalization)
#
#  dropout_97 (Dropout)           (None, 7, 7, 298)    0           ['batch_normalization_98[0][0]']
#
#  re_lu_98 (ReLU)                (None, 7, 7, 298)    0           ['dropout_97[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 7, 7, 12)     32196       ['re_lu_98[0][0]']
#
#  dense_block3_block17 (Concaten  (None, 7, 7, 310)   0           ['dense_block3_block16[0][0]',
#  ate)                                                             'conv2d_99[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 7, 7, 310)   1240        ['dense_block3_block17[0][0]']
#  ormalization)
#
#  dropout_98 (Dropout)           (None, 7, 7, 310)    0           ['batch_normalization_99[0][0]']
#
#  re_lu_99 (ReLU)                (None, 7, 7, 310)    0           ['dropout_98[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 7, 7, 12)     33492       ['re_lu_99[0][0]']
#
#  dense_block3_block18 (Concaten  (None, 7, 7, 322)   0           ['dense_block3_block17[0][0]',
#  ate)                                                             'conv2d_100[0][0]']
#
#  batch_normalization_100 (Batch  (None, 7, 7, 322)   1288        ['dense_block3_block18[0][0]']
#  Normalization)
#
#  dropout_99 (Dropout)           (None, 7, 7, 322)    0           ['batch_normalization_100[0][0]']
#
#  re_lu_100 (ReLU)               (None, 7, 7, 322)    0           ['dropout_99[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 7, 7, 12)     34788       ['re_lu_100[0][0]']
#
#  dense_block3_block19 (Concaten  (None, 7, 7, 334)   0           ['dense_block3_block18[0][0]',
#  ate)                                                             'conv2d_101[0][0]']
#
#  batch_normalization_101 (Batch  (None, 7, 7, 334)   1336        ['dense_block3_block19[0][0]']
#  Normalization)
#
#  dropout_100 (Dropout)          (None, 7, 7, 334)    0           ['batch_normalization_101[0][0]']
#
#  re_lu_101 (ReLU)               (None, 7, 7, 334)    0           ['dropout_100[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 7, 7, 12)     36084       ['re_lu_101[0][0]']
#
# ...
#
#  batch_normalization_111 (Batch  (None, 3, 3, 245)   980         ['dense_block4_block4[0][0]']
#  Normalization)
#
#  dropout_110 (Dropout)          (None, 3, 3, 245)    0           ['batch_normalization_111[0][0]']
#
#  re_lu_111 (ReLU)               (None, 3, 3, 245)    0           ['dropout_110[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 3, 3, 12)     26472       ['re_lu_111[0][0]']
#
#  dense_block4_block5 (Concatena  (None, 3, 3, 257)   0           ['dense_block4_block4[0][0]',
#  te)                                                              'conv2d_112[0][0]']
#
#  batch_normalization_112 (Batch  (None, 3, 3, 257)   1028        ['dense_block4_block5[0][0]']
#  Normalization)
#
#  dropout_111 (Dropout)          (None, 3, 3, 257)    0           ['batch_normalization_112[0][0]']
#
#  re_lu_112 (ReLU)               (None, 3, 3, 257)    0           ['dropout_111[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 3, 3, 12)     27768       ['re_lu_112[0][0]']
#
#  dense_block4_block6 (Concatena  (None, 3, 3, 269)   0           ['dense_block4_block5[0][0]',
#  te)                                                              'conv2d_113[0][0]']
#
#  batch_normalization_113 (Batch  (None, 3, 3, 269)   1076        ['dense_block4_block6[0][0]']
#  Normalization)
#
#  dropout_112 (Dropout)          (None, 3, 3, 269)    0           ['batch_normalization_113[0][0]']
#
#  re_lu_113 (ReLU)               (None, 3, 3, 269)    0           ['dropout_112[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 3, 3, 12)     29064       ['re_lu_113[0][0]']
#
#  dense_block4_block7 (Concatena  (None, 3, 3, 281)   0           ['dense_block4_block6[0][0]',
#  te)                                                              'conv2d_114[0][0]']
#
#  batch_normalization_114 (Batch  (None, 3, 3, 281)   1124        ['dense_block4_block7[0][0]']
#  Normalization)
#
#  dropout_113 (Dropout)          (None, 3, 3, 281)    0           ['batch_normalization_114[0][0]']
#
#  re_lu_114 (ReLU)               (None, 3, 3, 281)    0           ['dropout_113[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 3, 3, 12)     30360       ['re_lu_114[0][0]']
#
#  dense_block4_block8 (Concatena  (None, 3, 3, 293)   0           ['dense_block4_block7[0][0]',
#  te)                                                              'conv2d_115[0][0]']
#
#  batch_normalization_115 (Batch  (None, 3, 3, 293)   1172        ['dense_block4_block8[0][0]']
#  Normalization)
#
#  dropout_114 (Dropout)          (None, 3, 3, 293)    0           ['batch_normalization_115[0][0]']
#
#  re_lu_115 (ReLU)               (None, 3, 3, 293)    0           ['dropout_114[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 3, 3, 12)     31656       ['re_lu_115[0][0]']
#
#  dense_block4_block9 (Concatena  (None, 3, 3, 305)   0           ['dense_block4_block8[0][0]',
#  te)                                                              'conv2d_116[0][0]']
#
#  batch_normalization_116 (Batch  (None, 3, 3, 305)   1220        ['dense_block4_block9[0][0]']
#  Normalization)
#
#  dropout_115 (Dropout)          (None, 3, 3, 305)    0           ['batch_normalization_116[0][0]']
#
#  re_lu_116 (ReLU)               (None, 3, 3, 305)    0           ['dropout_115[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 3, 3, 12)     32952       ['re_lu_116[0][0]']
#
#  dense_block4_block10 (Concaten  (None, 3, 3, 317)   0           ['dense_block4_block9[0][0]',
#  ate)                                                             'conv2d_117[0][0]']
#
#  batch_normalization_117 (Batch  (None, 3, 3, 317)   1268        ['dense_block4_block10[0][0]']
#  Normalization)
#
#  dropout_116 (Dropout)          (None, 3, 3, 317)    0           ['batch_normalization_117[0][0]']
#
#  re_lu_117 (ReLU)               (None, 3, 3, 317)    0           ['dropout_116[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 3, 3, 12)     34248       ['re_lu_117[0][0]']
#
#  dense_block4_block11 (Concaten  (None, 3, 3, 329)   0           ['dense_block4_block10[0][0]',
#  ate)                                                             'conv2d_118[0][0]']
#
#  batch_normalization_118 (Batch  (None, 3, 3, 329)   1316        ['dense_block4_block11[0][0]']
#  Normalization)
#
#  dropout_117 (Dropout)          (None, 3, 3, 329)    0           ['batch_normalization_118[0][0]']
#
#  re_lu_118 (ReLU)               (None, 3, 3, 329)    0           ['dropout_117[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 3, 3, 12)     35544       ['re_lu_118[0][0]']
#
#  dense_block4_block12 (Concaten  (None, 3, 3, 341)   0           ['dense_block4_block11[0][0]',
#  ate)                                                             'conv2d_119[0][0]']
#
#  batch_normalization_119 (Batch  (None, 3, 3, 341)   1364        ['dense_block4_block12[0][0]']
#  Normalization)
#
#  dropout_118 (Dropout)          (None, 3, 3, 341)    0           ['batch_normalization_119[0][0]']
#
#  re_lu_119 (ReLU)               (None, 3, 3, 341)    0           ['dropout_118[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 3, 3, 12)     36840       ['re_lu_119[0][0]']
#
#  dense_block4_block13 (Concaten  (None, 3, 3, 353)   0           ['dense_block4_block12[0][0]',
#  ate)                                                             'conv2d_120[0][0]']
#
#  batch_normalization_120 (Batch  (None, 3, 3, 353)   1412        ['dense_block4_block13[0][0]']
#  Normalization)
#
#  dropout_119 (Dropout)          (None, 3, 3, 353)    0           ['batch_normalization_120[0][0]']
#
#  re_lu_120 (ReLU)               (None, 3, 3, 353)    0           ['dropout_119[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 3, 3, 12)     38136       ['re_lu_120[0][0]']
#
#  dense_block4_block14 (Concaten  (None, 3, 3, 365)   0           ['dense_block4_block13[0][0]',
#  ate)                                                             'conv2d_121[0][0]']
#
#  batch_normalization_121 (Batch  (None, 3, 3, 365)   1460        ['dense_block4_block14[0][0]']
#  Normalization)
#
#  dropout_120 (Dropout)          (None, 3, 3, 365)    0           ['batch_normalization_121[0][0]']
#
#  re_lu_121 (ReLU)               (None, 3, 3, 365)    0           ['dropout_120[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 3, 3, 12)     39432       ['re_lu_121[0][0]']
#
#  dense_block4_block15 (Concaten  (None, 3, 3, 377)   0           ['dense_block4_block14[0][0]',
#  ate)                                                             'conv2d_122[0][0]']
#
#  batch_normalization_122 (Batch  (None, 3, 3, 377)   1508        ['dense_block4_block15[0][0]']
#  Normalization)
#
#  dropout_121 (Dropout)          (None, 3, 3, 377)    0           ['batch_normalization_122[0][0]']
#
#  re_lu_122 (ReLU)               (None, 3, 3, 377)    0           ['dropout_121[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 3, 3, 12)     40728       ['re_lu_122[0][0]']
#
#  dense_block4_block16 (Concaten  (None, 3, 3, 389)   0           ['dense_block4_block15[0][0]',
#  ate)                                                             'conv2d_123[0][0]']
#
#  batch_normalization_123 (Batch  (None, 3, 3, 389)   1556        ['dense_block4_block16[0][0]']
#  Normalization)
#
#  dropout_122 (Dropout)          (None, 3, 3, 389)    0           ['batch_normalization_123[0][0]']
#
#  re_lu_123 (ReLU)               (None, 3, 3, 389)    0           ['dropout_122[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 389)         0           ['re_lu_123[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 10)           3900        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 1,533,997
# Trainable params: 1,506,495
# Non-trainable params: 27,502
# __________________________________________________________________________________________________

# %%
from livelossplot import PlotLossesKeras
import time 

start = time.time() 
model_history = model.fit(train_dataset, validation_data=val_dataset, epochs=300, callbacks=[PlotLossesKeras()], verbose=False)
end = time.time() - start 
print("Время: "+ str(end) +' секунд')
# Out:
# accuracy
# 	training         	 (min:    0.957, max:    0.967, cur:    0.967)
# 	validation       	 (min:    0.929, max:    0.953, cur:    0.946)
# Loss
# 	training         	 (min:    0.114, max:    0.147, cur:    0.114)
# 	validation       	 (min:    0.199, max:    0.270, cur:    0.230)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-b6772be912f7> in <cell line: 5>()
#       3
#       4 start = time.time()
# ----> 5 model_history = model.fit(train_dataset, validation_data=val_dataset, epochs=300, callbacks=[PlotLossesKeras()], verbose=False)
#       6 end = time.time() - start
#       7 print("Время: "+ str(end) +' секунд')
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.save("my_model")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-5a8adf13c269> in <cell line: 1>()
# ----> 1 model.save("my_model")
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in save(self, filepath, overwrite, save_format, **kwargs)
#    2824         Note that `model.save()` is an alias for `tf.keras.models.save_model()`.
#    2825         """
# -> 2826         saving_api.save_model(
#    2827             self,
#    2828             filepath=filepath,
#
# /usr/local/lib/python3.9/dist-packages/keras/saving/saving_api.py in save_model(model, filepath, overwrite, save_format, **kwargs)
#     143     else:
#     144         # Legacy case
# --> 145         return legacy_sm_saving_lib.save_model(
#     146             model,
#     147             filepath,
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/saving/legacy/save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     166                 save_traces=save_traces, in_tf_saved_model_scope=True
#     167             ):
# --> 168                 saved_model_save.save(
#     169                     model,
#     170                     filepath,
#
# /usr/local/lib/python3.9/dist-packages/keras/saving/legacy/saved_model/save.py in save(model, filepath, overwrite, include_optimizer, signatures, options, save_traces)
#      96         with backend.deprecated_internal_learning_phase_scope(0):
#      97             with utils.keras_option_scope(save_traces):
# ---> 98                 saved_nodes, node_paths = save_lib.save_and_return_nodes(
#      99                     model, filepath, signatures, options
#     100                 )
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/saved_model/save.py in save_and_return_nodes(obj, export_dir, signatures, options, experimental_skip_checkpoint)
#    1274
#    1275   _, exported_graph, object_saver, asset_info, saved_nodes, node_paths = (
# -> 1276       _build_meta_graph(obj, signatures, options, meta_graph_def))
#    1277   saved_model.saved_model_schema_version = (
#    1278       constants.SAVED_MODEL_SCHEMA_VERSION)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/saved_model/save.py in _build_meta_graph(obj, signatures, options, meta_graph_def)
#    1453
#    1454   with save_context.save_context(options):
# -> 1455     return _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/saved_model/save.py in _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#    1396   augmented_graph_view = _AugmentedGraphView(obj)
#    1397   if signatures is None:
# -> 1398     signatures = signature_serialization.find_function_to_export(
#    1399         augmented_graph_view)
#    1400
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/saved_model/signature_serialization.py in find_function_to_export(saveable_view)
#     101   # serving that model way later in the process stops working.
#     102   possible_signatures = []
# --> 103   for name, child in children:
#     104     if not isinstance(child, (def_function.Function, defun.ConcreteFunction)):
#     105       continue
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/saved_model/save.py in list_children(self, obj)
#     178       children = self._children_cache[obj] = {}
#     179
# --> 180       for name, child in super(_AugmentedGraphView, self).list_children(
#     181           obj,
#     182           save_type=base.SaveType.SAVEDMODEL,
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/checkpoint/graph_view.py in list_children(self, obj, save_type, **kwargs)
#      73     """
#      74     children = []
# ---> 75     for name, ref in super(ObjectGraphView,
#      76                            self).children(obj, save_type, **kwargs).items():
#      77       children.append(base.TrackableReference(name, ref))
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/checkpoint/trackable_view.py in children(cls, obj, save_type, **kwargs)
#      82     obj._maybe_initialize_trackable()
#      83     children = {}
# ---> 84     for name, ref in obj._trackable_children(save_type, **kwargs).items():
#      85       ref = converter.convert_to_trackable(ref, parent=obj)
#      86       children[name] = ref
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/functional.py in _trackable_children(self, save_type, **kwargs)
#     459     def _trackable_children(self, save_type="checkpoint", **kwargs):
#     460         dependencies = self._layer_checkpoint_dependencies
# --> 461         dependencies.update(super()._trackable_children(save_type, **kwargs))
#     462         return dependencies
#     463
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in _trackable_children(self, save_type, **kwargs)
#    3731             self.train_tf_function = None
#    3732
# -> 3733         children = super()._trackable_children(save_type, **kwargs)
#    3734
#    3735         if save_type == "savedmodel":
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/base_layer.py in _trackable_children(self, save_type, **kwargs)
#    3469         else:
#    3470             children = {}
# -> 3471         children.update(super()._trackable_children(save_type, **kwargs))
#    3472         return children
#    3473
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/trackable/autotrackable.py in _trackable_children(self, save_type, **kwargs)
#      93           with warnings.catch_warnings():
#      94             warnings.simplefilter("ignore")
# ---> 95             attribute_value = getattr(self, attribute_name, None)
#      96         except Exception:  # pylint: disable=broad-except
#      97           # NOTE: If we make the exception catching here less broad, we might
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/base_layer.py in _tracking_metadata(self)
#    3456     def _tracking_metadata(self):
#    3457         """Info about this layer to be saved into the SavedModel."""
# -> 3458         return self._trackable_saved_model_saver.tracking_metadata
#    3459
#    3460     def _trackable_children(self, save_type="checkpoint", **kwargs):
#
# /usr/local/lib/python3.9/dist-packages/keras/saving/legacy/saved_model/base_serialization.py in tracking_metadata(self)
#      52         # TODO(kathywu): check that serialized JSON can be loaded (e.g., if an
#      53         # object is in the python property)
# ---> 54         return json_utils.Encoder().encode(self.python_properties)
#      55
#      56     def trackable_children(self, serialization_cache):
#
# /usr/local/lib/python3.9/dist-packages/keras/saving/legacy/saved_model/layer_serialization.py in python_properties(self)
#      35     def python_properties(self):
#      36         # TODO(kathywu): Add python property validator
# ---> 37         return self._python_properties_internal()
#      38
#      39     def _python_properties_internal(self):
#
# /usr/local/lib/python3.9/dist-packages/keras/saving/legacy/saved_model/model_serialization.py in _python_properties_internal(self)
#      39
#      40         metadata.update(
# ---> 41             saving_utils.model_metadata(
#      42                 self.obj, include_optimizer=True, require_config=False
#      43             )
#
# /usr/local/lib/python3.9/dist-packages/keras/saving/legacy/saving_utils.py in model_metadata(model, include_optimizer, require_config)
#     166     model_config = {"class_name": model.__class__.__name__}
#     167     try:
# --> 168         model_config["config"] = model.get_config()
#     169     except NotImplementedError as e:
#     170         if require_config:
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/functional.py in get_config(self)
#     774             # SavedModel special case: need to preserve legacy (potentially
#     775             # incorrect) behavior.
# --> 776             return copy.deepcopy(get_network_config(self, config=config))
#     777
#     778         # Check whether the class has a constructor compatible with a Functional
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/functional.py in get_network_config(network, serialize_layer_fn, config)
#    1570                     # The node is relevant to the model:
#    1571                     # add to filtered_inbound_nodes.
# -> 1572                     node_data = node.serialize(
#    1573                         _make_node_key, node_conversion_map
#    1574                     )
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/node.py in serialize(self, make_node_key, node_conversion_map)
#     217             return t
#     218
# --> 219         kwargs = tf.nest.map_structure(_serialize_keras_tensor, kwargs)
#     220         try:
#     221             json.dumps(kwargs, default=json_utils.get_json_type)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     899     raise ValueError("Must provide at least one structure")
#     900
# --> 901   check_types = kwargs.pop("check_types", True)
#     902   expand_composites = kwargs.pop("expand_composites", False)
#     903
#
# KeyboardInterrupt:

# %%
import numpy as np 

# Приводим в единный массив из двойного (может есть оптимальней)
predictions = model.predict(x_test)
new_predictions = []
for i in predictions:
  i = list(i)
  max_i = max(i)
  index_max_i = i.index(max_i)
  new_predictions.append(index_max_i)
# Out:
# 782/782 [==============================] - 9s 12ms/step

# %%
import pandas as pd   #  pip install pandas

columns=['Id', 'Category']

data = []
data.append(np.arange(len(new_predictions)))
data.append(new_predictions)
data = np.array(data).T
df = pd.DataFrame(data, columns=columns)
df['Id'] = df['Id'].astype(int)

df.to_csv('/content/cartridge_accounting_DenseNet_2-2.csv', index= False )
